# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Create visualizations using Matplotib, Seaborn and Folium**
#
# Estimated time needed: **40** minutes
#
# In this assignment, you will have the opportunity to demonstrate the skills you have acquired in creating visualizations using *Matplotlib, Seaborn, Folium*.
# <br>
# <br>
# <span style="color:red">After each task you will be required to save your plots as an image or screenshot using the filenames specified.  You will be uploading these images during your final project submission so they can be evaluated by your peers. </span>

# %% [markdown]
# # __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             </ol>
#     </li>
#     <li>
#         <a href="#Scenario">Scenario</a>
#         <ol>
#             <li><a href="#Data Description">Data Description</a></li>
#         </ol>
#     </li>
#     <li><a href="#Importing Data">Importing data</a></li>
#     <li><a href="#Creating Visualizations for Data Analysis">Creating Visualizations for Data Analysis</a></li>
# </ol>

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
# - Create informative and visually appealing plots with Matplotlib and Seaborn.
# - Apply visualization to communicate insights from the data.
# - Analyze data through using visualizations.
# - Customize visualizations

# %% [markdown]
# # Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for plotting.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for plotting.
# *  [`Folium`](https://python-visualization.github.io/folium/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for plotting.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run these notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `%pip` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# %pip install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 seaborn folium
# Note: If your environment doesn't support "%pip install", use "!mamba install"

# %%
# %pip install seaborn
# %pip install folium

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
# You will require:-
# <br>Numpy for many scientific computing in Python
# <br>Pandas for creating and working on dataframe, also for plotting directly on dataframe/series
# <br>The inline backend to generate the plots within the browser [%matplotlib inline]
# <br>Matplotlib and its pyplot pacakge for plotting
# <br>Seaborn for plotting
# </details>

# %% [markdown]
# <details><summary>Click here for python solution</summary>
#
# ```python
#     #Import Primary Modules:
#     import numpy as np
#     import pandas as pd
#     %matplotlib inline
#     import matplotlib as mpl
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import folium
# ```
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# # Scenario
#
# In this assignment you will be tasked with creating plots which answer questions for analysing "historical_automobile_sales" data to understand the historical trends in automobile sales during recession periods.<br>
# recession period 1 - year 1980 <br>
# recession period 2 - year 1981 to 1982<br>
# recession period 3 - year 1991<br>
# recession period 4 - year 2000 to 2001<br>
# recession period 5 - year end 2007 to mid 2009<br>
# recession period 6 - year 2020 -Feb to April (Covid-19 Impact)<br>
#
# # Data Description
#
# The dataset used for this visualization assignment contains *historical_automobile_sales* data representing automobile sales and related variables during recession and non-recession period.
#
# The dataset includes the following variables:
# <br>1. Date: The date of the observation.
# <br>2. Recession: A binary variable indicating recession perion; 1 means it was recession, 0 means it was normal.
# <br>3. Automobile_Sales: The number of vehicles sold during the period.
# <br>4. GDP: The per capita GDP value in USD.
# <br>5. Unemployment_Rate: The monthly unemployment rate.
# <br>6. Consumer_Confidence: A synthetic index representing consumer confidence, which can impact consumer spending and automobile purchases.
# <br>7. Seasonality_Weight: The weight representing the seasonality effect on automobile sales during the period.
# <br>8. Price: The average vehicle price during the period.
# <br>9. Advertising_Expenditure: The advertising expenditure of the company.
# <br>10.Vehicle_Type: The type of vehicles sold; Supperminicar, Smallfamiliycar,                 Mediumfamilycar, Executivecar, Sports.
# <br>11.Competition: The measure of competition in the market, such as the number of competitors or market share of major manufacturers.
# <br>12.Month: Month of the observation extracted from Date..
# <br>13.Year: Year of the observation extracted from Date.
# <br>
# By examining various factors mentioned above from the dataset, you aim to gain insights into how recessions impacted automobile sales for your company.

# %% [markdown]
# ---

# %% [markdown]
# # Importing Data

# %% [markdown]
# #### For your convenience, we have already written code to import the data below.

# %%
import requests
import io
import pandas as pd

# URL of the CSV file
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv"

# Fetch the data from the URL
response = requests.get(URL)

# Raise an error if the request failed
response.raise_for_status()

# Convert the response content into a readable format for pandas
csv_content = io.StringIO(response.text)

# Read the CSV data into a pandas dataframe
df = pd.read_csv(csv_content)

# Print confirmation
print('Data downloaded and read into a dataframe!')

# Optional: Show the first few rows of the dataframe
print(df.head())
# Out:
# Data downloaded and read into a dataframe!
#         Date  Year Month  Recession  Consumer_Confidence  Seasonality_Weight  \
# 0  1/31/1980  1980   Jan          1               108.24                0.50
# 1  2/29/1980  1980   Feb          1                98.75                0.75
# 2  3/31/1980  1980   Mar          1               107.48                0.20
# 3  4/30/1980  1980   Apr          1               115.01                1.00
# 4  5/31/1980  1980   May          1                98.72                0.20
#
#        Price  Advertising_Expenditure  Competition     GDP  Growth_Rate  \
# 0  27483.571                     1558            7  60.223     0.010000
# 1  24308.678                     3048            4  45.986    -0.309594
# 2  28238.443                     3137            3  35.141    -0.308614
# 3  32615.149                     1653            7  45.673     0.230596
# 4  23829.233                     1319            4  52.997     0.138197
#
#    unemployment_rate  Automobile_Sales     Vehicle_Type        City
# 0                5.4             456.0    Supperminicar     Georgia
# 1                4.8             555.9    Supperminicar    New York
# 2                3.4             620.0  Mediumfamilycar    New York
# 3                4.2             702.8    Supperminicar    Illinois
# 4                5.3             770.4  Smallfamiliycar  California

# %%
df.describe()
# Out:
#               Year   Recession  Consumer_Confidence  Seasonality_Weight  \
# count   528.000000  528.000000           528.000000          528.000000
# mean   2001.500000    0.214015           101.140170            0.575795
# std      12.710467    0.410526            10.601154            0.454477
# min    1980.000000    0.000000            73.900000            0.000000
# 25%    1990.750000    0.000000            94.035000            0.250000
# 50%    2001.500000    0.000000           100.740000            0.500000
# 75%    2012.250000    0.000000           108.240000            0.750000
# max    2023.000000    1.000000           131.670000            1.500000
#
#               Price  Advertising_Expenditure  Competition         GDP  \
# count    528.000000               528.000000   528.000000  528.000000
# mean   24964.991956              3067.456439     6.064394   40.073903
# std     4888.073433              1139.564637     1.968350   16.249714
# min     8793.663000              1009.000000     3.000000   12.508000
# 25%    21453.300500              2083.500000     4.000000   27.237500
# 50%    25038.691500              3072.000000     6.000000   39.214500
# 75%    28131.684750              4067.250000     8.000000   53.506500
# max    44263.657000              4983.000000     9.000000   70.374000
#
#        Growth_Rate  unemployment_rate  Automobile_Sales
# count   528.000000         528.000000        528.000000
# mean     -0.242001           2.453977       2352.718068
# std       0.861268           1.119019       1645.321284
# min      -4.227601           1.000000        102.000000
# 25%      -0.574049           1.600000        793.950000
# 50%      -0.013162           2.300000       2182.600000
# 75%       0.388932           2.900000       3614.800000
# max       0.815074           6.000000      21147.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     528 non-null    object
#  1   Year                     528 non-null    int64
#  2   Month                    528 non-null    object
#  3   Recession                528 non-null    int64
#  4   Consumer_Confidence      528 non-null    float64
#  5   Seasonality_Weight       528 non-null    float64
#  6   Price                    528 non-null    float64
#  7   Advertising_Expenditure  528 non-null    int64
#  8   Competition              528 non-null    int64
#  9   GDP                      528 non-null    float64
#  10  Growth_Rate              528 non-null    float64
#  11  unemployment_rate        528 non-null    float64
#  12  Automobile_Sales         528 non-null    float64
#  13  Vehicle_Type             528 non-null    object
#  14  City                     528 non-null    object
# dtypes: float64(7), int64(4), object(4)
# memory usage: 62.0+ KB

# %% [markdown]
# ---

# %% [markdown]
# # Creating Visualizations for Data Analysis

# %% [markdown]
# ### TASK 1.1: Develop a *Line chart* using the functionality of pandas to show how automobile sales fluctuate from year to year

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
# You will require:-
# <br>to group the year and calculate the average on the 'Automobile Sales', as the data has years and months column
# <br>make use of .plot() with kind = 'line'
# <br>donot forget to include labels and title
# </details>

# %%
df1=df.groupby('Year')['Automobile_Sales'].mean().reset_index()
df1.plot(kind='line',x='Year',y='Automobile_Sales')
plt.title('Automobile Sales From 1980 to 2023')
plt.xlabel('Year')
plt.ylabel('Automobile Sales')
plt.show()

# %% [markdown]
# <details><summary>Click here for a solution template</summary>
#
# ```python
#     #create data for plotting
#     df_line = df.groupby(df['Year'])['Automobile_Sales'].mean()
#     #create figure
#     plt.figure(figsize=(10, 6))
#     df_line.plot(kind = 'line')
#     plt.xlabel('........')
#     plt.ylabel('.........')
#     plt.title('......................')
#     plt.show()
# ```
# </details>

# %% [markdown]
# ### Include the following on the plot
# ticks on x- axis with all the years, to identify the years of recession
# <br>annotation for at least two years of recession
# <br>Title as Automobile Sales during Recession
# <br>

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#     <p>
#     You can create the list for the range 1980 till 2023 and pass that list to the plt.xticks function or you can directly pass the range to the function.
#     You might need to rotate the ticks to an angle so that they fit in well on the axis
#     You can include annotation with plt.text(x, y, 'text to display')
#     </p>
# </details>

# %%
df1=df.groupby('Year')['Automobile_Sales'].mean().reset_index()

df1.plot(kind='line',x='Year',y='Automobile_Sales',figsize=(14,8))
plt.xticks(list(map(int,range(1980,2024))),rotation=75)
plt.title('Automobile Sales during Recession')
plt.xlabel('Year')
plt.ylabel('Automobile Sales')
plt.text(1989,800,'1991 Recession')
plt.text(1999,1200,'2000-01 Recession')
plt.text(2007,1000,'2007-09 Recession')
plt.show()

# %% [markdown]
# <details>
#     <summary>Click here for Solution template</summary>
#
# ```python
#     plt.figure(figsize=(10, 6))
#     df_line = ...............
#     df_line.plot(kind = 'line')
#     plt.xticks(list(range(1980,2024)), rotation = 75)
#     plt.xlabel('..............')
#     plt.ylabel('............')
#     plt.title('...................')
#     plt.text(1982, 650, '1981-82 Recession')
#     plt.text(......, ..., '..............')
#     plt.legend()
#     plt.show()
# ```
#
# </details>

# %%
plt.figure(figsize=(10, 6))
df_line = df.groupby(df['Year'])['Automobile_Sales'].mean()
df_line.plot(kind = 'line')
plt.xticks(list(range(1980,2024)), rotation = 75)

plt.text(1982, 650, '1981-82 Recession')

plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red">
# Save this plot as "Line_Plot_1.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
# ####  TASK 1.2: Plot different lines for categories of vehicle type and analyse the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?

# %%
df
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# 5     6/30/1980  1980   Jun          1               105.55
# 6     7/31/1980  1980   Jul          1                82.45
# 7     8/31/1980  1980   Aug          1                98.76
# 8     9/30/1980  1980   Sep          1                87.68
# 9    10/31/1980  1980   Oct          1               101.45
# 10   11/30/1980  1980   Nov          1               102.36
# 11   12/31/1980  1980   Dec          1               102.33
# 12    1/31/1981  1981   Jan          1                95.20
# 13    2/28/1981  1981   Feb          1               122.98
# 14    3/31/1981  1981   Mar          1                87.32
# 15    4/30/1981  1981   Apr          1                86.71
# 16    5/31/1981  1981   May          1               116.55
# 17    6/30/1981  1981   Jun          1                92.96
# 18    7/31/1981  1981   Jul          1                90.55
# 19    8/31/1981  1981   Aug          1               123.03
# 20    9/30/1981  1981   Sep          1               109.86
# 21   10/31/1981  1981   Oct          1                94.06
# 22   11/30/1981  1981   Nov          1               102.18
# 23   12/31/1981  1981   Dec          1               119.46
# 24    1/31/1982  1982   Jan          1               106.92
# 25    2/28/1982  1982   Feb          1               112.86
# 26    3/31/1982  1982   Mar          1               108.05
# 27    4/30/1982  1982   Apr          1               109.30
# 28    5/31/1982  1982   May          1               100.40
# 29    6/30/1982  1982   Jun          1               100.11
# 30    7/31/1982  1982   Jul          1               102.67
# 31    8/31/1982  1982   Aug          1               107.34
# 32    9/30/1982  1982   Sep          1                97.17
# 33   10/31/1982  1982   Oct          1               101.22
# 34   11/30/1982  1982   Nov          1                96.90
# 35   12/31/1982  1982   Dec          1               101.16
# 36    1/31/1983  1983   Jan          1                87.49
# 37    2/28/1990  1990   Feb          1                93.69
# 38    3/31/1990  1990   Mar          1               109.07
# 39    4/30/1990  1990   Apr          1               100.36
# 40    5/31/1990  1990   May          1               118.65
# 41    6/30/1990  1990   Jun          1               108.20
# 42    7/31/1990  1990   Jul          1               111.04
# 43    8/31/1990  1990   Aug          1               101.33
# 44    9/30/1990  1990   Sep          1               101.57
# 45   10/31/1990  1990   Oct          1               117.31
# 46   11/30/1990  1990   Nov          1                96.22
# 47   12/31/1990  1990   Dec          1               105.47
# 48    1/31/1991  1991   Jan          1                97.34
# 49    2/28/1991  1991   Feb          1                97.31
# 50    3/31/1991  1991   Mar          1                88.31
# 51    4/30/1991  1991   Apr          1                92.57
# 52    5/31/1991  1991   May          1                90.72
# 53    6/30/1991  1991   Jun          1               105.94
# 54    7/31/1991  1991   Jul          1               110.40
# 55    8/31/1991  1991   Aug          1                99.05
# 56    9/30/1991  1991   Sep          1               102.30
# 57   10/31/1991  1991   Oct          1                98.48
# 58   11/30/1991  1991   Nov          1                91.89
# 59   12/31/1991  1991   Dec          1               108.62
# 60    1/31/1992  1992   Jan          1               106.53
# 61    2/29/1992  1992   Feb          1                81.07
# 62    3/31/1992  1992   Mar          1                97.17
# 63    4/30/2000  2000   Apr          1               119.77
# 64    5/31/2000  2000   May          1               113.51
# 65    6/30/2000  2000   Jun          1               104.64
# 66    7/31/2000  2000   Jul          1                94.20
# 67    8/31/2000  2000   Aug          1                99.76
# 68    9/30/2000  2000   Sep          1                97.78
# 69   10/31/2000  2000   Oct          1                87.85
# 70   11/30/2000  2000   Nov          1               106.50
# 71   12/31/2000  2000   Dec          1               115.67
# 72    1/31/2001  2001   Jan          1                97.02
# 73    2/28/2001  2001   Feb          1               121.64
# 74    3/31/2001  2001   Mar          1                84.42
# 75    4/30/2001  2001   Apr          1               110.54
# 76    5/31/2001  2001   May          1               116.72
# 77    6/30/2001  2001   Jun          1                97.96
# 78    7/31/2001  2001   Jul          1                98.14
# 79    8/31/2001  2001   Aug          1               110.43
# 80    9/30/2001  2001   Sep          1               105.06
# 81   10/31/2001  2001   Oct          1                80.03
# 82   11/30/2001  2001   Nov          1                91.57
# 83   12/31/2001  2001   Dec          1                99.86
# 84    1/31/2002  2002   Jan          1                86.30
# 85    2/28/2002  2002   Feb          1                95.26
# 86    3/31/2002  2002   Mar          1                86.55
# 87    4/30/2002  2002   Apr          1                96.30
# 88    4/30/2008  2008   Apr          1                91.05
# 89    5/31/2008  2008   May          1                91.19
# 90    6/30/2008  2008   Jun          1               116.16
# 91    7/31/2008  2008   Jul          1               119.72
# 92    8/31/2008  2008   Aug          1                97.87
# 93    9/30/2008  2008   Sep          1               100.68
# 94   10/31/2008  2008   Oct          1               104.00
# 95   11/30/2008  2008   Nov          1               101.48
# 96   12/31/2008  2008   Dec          1                83.26
# 97    1/31/2009  2009   Jan          1               104.28
# 98    2/28/2009  2009   Feb          1                79.12
# 99    3/31/2009  2009   Mar          1                92.67
# 100   4/30/2009  2009   Apr          1               105.05
# 101   5/31/2009  2009   May          1               106.00
# 102   6/30/2009  2009   Jun          1                91.90
# 103   7/31/2009  2009   Jul          1                95.42
# 104   8/31/2009  2009   Aug          1                94.06
# 105   9/30/2009  2009   Sep          1                98.97
# 106  10/31/2009  2009   Oct          1                99.73
# 107  11/30/2009  2009   Nov          1               106.68
# 108  12/31/2009  2009   Dec          1                94.83
# 109   9/30/2020  2020   Sep          1               111.62
# 110  10/31/2020  2020   Oct          1                84.48
# 111  11/30/2020  2020   Nov          1               112.39
# 112  12/31/2020  2020   Dec          1                97.85
# 113   2/28/1983  1983   Feb          0               126.06
# 114   3/31/1983  1983   Mar          0                92.67
# 115   4/30/1983  1983   Apr          0                96.39
# 116   5/31/1983  1983   May          0                91.81
# 117   6/30/1983  1983   Jun          0               106.16
# 118   7/31/1983  1983   Jul          0                98.04
# 119   8/31/1983  1983   Aug          0                90.36
# 120   9/30/1983  1983   Sep          0               106.57
# 121  10/31/1983  1983   Oct          0               107.92
# 122  11/30/1983  1983   Nov          0                99.33
# 123  12/31/1983  1983   Dec          0                93.36
# 124   1/31/1984  1984   Jan          0               121.91
# 125   2/29/1984  1984   Feb          0               103.40
# 126   3/31/1984  1984   Mar          0                87.26
# 127   4/30/1984  1984   Apr          0               114.14
# 128   5/31/1984  1984   May          0                91.44
# 129   6/30/1984  1984   Jun          0               127.42
# 130   7/31/1984  1984   Jul          0               100.80
# 131   8/31/1984  1984   Aug          0               110.13
# 132   9/30/1984  1984   Sep          0                79.20
# 133  10/31/1984  1984   Oct          0                87.16
# 134  11/30/1984  1984   Nov          0               113.34
# 135  12/31/1984  1984   Dec          0               103.18
# 136   1/31/1985  1985   Jan          0               120.42
# 137   2/28/1985  1985   Feb          0               104.85
# 138   3/31/1985  1985   Mar          0               101.45
# 139   4/30/1985  1985   Apr          0               117.14
# 140   5/31/1985  1985   May          0               110.10
# 141   6/30/1985  1985   Jun          0                98.04
# 142   7/31/1985  1985   Jul          0                89.06
# 143   8/31/1985  1985   Aug          0                76.28
# 144   9/30/1985  1985   Sep          0                95.62
# 145  10/31/1985  1985   Oct          0                88.14
# 146  11/30/1985  1985   Nov          0               125.98
# 147  12/31/1985  1985   Dec          0                93.50
# 148   1/31/1986  1986   Jan          0                93.22
# 149   2/28/1986  1986   Feb          0                84.79
# 150   3/31/1986  1986   Mar          0                97.34
# 151   4/30/1986  1986   Apr          0                93.35
# 152   5/31/1986  1986   May          0               117.38
# 153   6/30/1986  1986   Jun          0               101.68
# 154   7/31/1986  1986   Jul          0                99.91
# 155   8/31/1986  1986   Aug          0                98.65
# 156   9/30/1986  1986   Sep          0               107.86
# 157  10/31/1986  1986   Oct          0                95.48
# 158  11/30/1986  1986   Nov          0               106.67
# 159  12/31/1986  1986   Dec          0               116.14
# 160   1/31/1987  1987   Jan          0               104.60
# 161   2/28/1987  1987   Feb          0                97.50
# 162   3/31/1987  1987   Mar          0                90.47
# 163   4/30/1987  1987   Apr          0                97.25
# 164   5/31/1987  1987   May          0               105.63
# 165   6/30/1987  1987   Jun          0                84.67
# 166   7/31/1987  1987   Jul          0               108.32
# 167   8/31/1987  1987   Aug          0               102.08
# 168   9/30/1987  1987   Sep          0                98.51
# 169  10/31/1987  1987   Oct          0                93.41
# 170  11/30/1987  1987   Nov          0                95.24
# 171  12/31/1987  1987   Dec          0               105.97
# 172   1/31/1988  1988   Jan          0                98.72
# 173   2/29/1988  1988   Feb          0                94.99
# 174   3/31/1988  1988   Mar          0               104.69
# 175   4/30/1988  1988   Apr          0               105.08
# 176   5/31/1988  1988   May          0                87.51
# 177   6/30/1988  1988   Jun          0               105.71
# 178   7/31/1988  1988   Jul          0               125.02
# 179   8/31/1988  1988   Aug          0               104.70
# 180   9/30/1988  1988   Sep          0                83.01
# 181  10/31/1988  1988   Oct          0               101.77
# 182  11/30/1988  1988   Nov          0                81.69
# 183  12/31/1988  1988   Dec          0               131.67
# 184   1/31/1989  1989   Jan          0               122.36
# 185   2/28/1989  1989   Feb          0                93.34
# 186   3/31/1989  1989   Mar          0                77.54
# 187   4/30/1989  1989   Apr          0                91.22
# 188   5/31/1989  1989   May          0                98.19
# 189   6/30/1989  1989   Jun          0                82.38
# 190   7/31/1989  1989   Jul          0                99.31
# 191   8/31/1989  1989   Aug          0                98.12
# 192   9/30/1989  1989   Sep          0               101.25
# 193  10/31/1989  1989   Oct          0               102.30
# 194  11/30/1989  1989   Nov          0                90.34
# 195  12/31/1989  1989   Dec          0                91.47
# 196   1/31/1990  1990   Jan          0               100.46
# 197   4/30/1992  1992   Apr          0                91.18
# 198   5/31/1992  1992   May          0                96.09
# 199   6/30/1992  1992   Jun          0                93.30
# 200   7/31/1992  1992   Jul          0                99.54
# 201   8/31/1992  1992   Aug          0                96.70
# 202   9/30/1992  1992   Sep          0                96.49
# 203  10/31/1992  1992   Oct          0               111.07
# 204  11/30/1992  1992   Nov          0               105.57
# 205  12/31/1992  1992   Dec          0                92.96
# 206   1/31/1993  1993   Jan          0                94.44
# 207   2/28/1993  1993   Feb          0               104.92
# 208   3/31/1993  1993   Mar          0               104.90
# 209   4/30/1993  1993   Apr          0                93.96
# 210   5/31/1993  1993   May          0                97.66
# 211   6/30/1993  1993   Jun          0               118.47
# 212   7/31/1993  1993   Jul          0                94.13
# 213   8/31/1993  1993   Aug          0               119.11
# 214   9/30/1993  1993   Sep          0               111.04
# 215  10/31/1993  1993   Oct          0               117.25
# 216  11/30/1993  1993   Nov          0                93.71
# 217  12/31/1993  1993   Dec          0                98.31
# 218   1/31/1994  1994   Jan          0                95.51
# 219   2/28/1994  1994   Feb          0               111.27
# 220   3/31/1994  1994   Mar          0                94.32
# 221   4/30/1994  1994   Apr          0               107.31
# 222   5/31/1994  1994   May          0               106.78
# 223   6/30/1994  1994   Jun          0                99.52
# 224   7/31/1994  1994   Jul          0               112.99
# 225   8/31/1994  1994   Aug          0               101.08
# 226   9/30/1994  1994   Sep          0               108.34
# 227  10/31/1994  1994   Oct          0                95.05
# 228  11/30/1994  1994   Nov          0                92.77
# 229  12/31/1994  1994   Dec          0               107.31
# 230   1/31/1995  1995   Jan          0               104.31
# 231   2/28/1995  1995   Feb          0               102.43
# 232   3/31/1995  1995   Mar          0                96.56
# 233   4/30/1995  1995   Apr          0               115.49
# 234   5/31/1995  1995   May          0                88.83
# 235   6/30/1995  1995   Jun          0                88.29
# 236   7/31/1995  1995   Jul          0               109.42
# 237   8/31/1995  1995   Aug          0               108.60
# 238   9/30/1995  1995   Sep          0               103.54
# 239  10/31/1995  1995   Oct          0                97.12
# 240  11/30/1995  1995   Nov          0               105.02
# 241  12/31/1995  1995   Dec          0               117.21
# 242   1/31/1996  1996   Jan          0               125.16
# 243   2/29/1996  1996   Feb          0                83.44
# 244   3/31/1996  1996   Mar          0                95.81
# 245   4/30/1996  1996   Apr          0                95.18
# 246   5/31/1996  1996   May          0               116.27
# 247   6/30/1996  1996   Jun          0                75.19
# 248   7/31/1996  1996   Jul          0               105.14
# 249   8/31/1996  1996   Aug          0                97.43
# 250   9/30/1996  1996   Sep          0               116.38
# 251  10/31/1996  1996   Oct          0               115.01
# 252  11/30/1996  1996   Nov          0               103.66
# 253  12/31/1996  1996   Dec          0                84.20
# 254   1/31/1997  1997   Jan          0                94.26
# 255   2/28/1997  1997   Feb          0                95.36
# 256   3/31/1997  1997   Mar          0                86.74
# 257   4/30/1997  1997   Apr          0               111.55
# 258   5/31/1997  1997   May          0                85.47
# 259   6/30/1997  1997   Jun          0               119.65
# 260   7/31/1997  1997   Jul          0               119.63
# 261   8/31/1997  1997   Aug          0                96.15
# 262   9/30/1997  1997   Sep          0               103.28
# 263  10/31/1997  1997   Oct          0                99.28
# 264  11/30/1997  1997   Nov          0               109.02
# 265  12/31/1997  1997   Dec          0               112.75
# 266   1/31/1998  1998   Jan          0               102.58
# 267   2/28/1998  1998   Feb          0               104.69
# 268   3/31/1998  1998   Mar          0                93.79
# 269   4/30/1998  1998   Apr          0               104.37
# 270   5/31/1998  1998   May          0               101.63
# 271   6/30/1998  1998   Jun          0                90.88
# 272   7/31/1998  1998   Jul          0                99.86
# 273   8/31/1998  1998   Aug          0                96.17
# 274   9/30/1998  1998   Sep          0                93.91
# 275  10/31/1998  1998   Oct          0                88.54
# 276  11/30/1998  1998   Nov          0               100.63
# 277  12/31/1998  1998   Dec          0                92.20
# 278   1/31/1999  1999   Jan          0                95.29
# 279   2/28/1999  1999   Feb          0               110.75
# 280   3/31/1999  1999   Mar          0               106.32
# 281   4/30/1999  1999   Apr          0                90.21
# 282   5/31/1999  1999   May          0               103.52
# 283   6/30/1999  1999   Jun          0               101.33
# 284   7/31/1999  1999   Jul          0               117.02
# 285   8/31/1999  1999   Aug          0               113.83
# 286   9/30/1999  1999   Sep          0                84.66
# 287  10/31/1999  1999   Oct          0               108.61
# 288  11/30/1999  1999   Nov          0               112.65
# 289  12/31/1999  1999   Dec          0               105.59
# 290   1/31/2000  2000   Jan          0                96.65
# 291   2/29/2000  2000   Feb          0               124.13
# 292   3/31/2000  2000   Mar          0               106.51
# 293   5/31/2002  2002   May          0                96.63
# 294   6/30/2002  2002   Jun          0               103.52
# 295   7/31/2002  2002   Jul          0                99.08
# 296   8/31/2002  2002   Aug          0               105.03
# 297   9/30/2002  2002   Sep          0               103.84
# 298  10/31/2002  2002   Oct          0               110.31
# 299  11/30/2002  2002   Nov          0               108.74
# 300  12/31/2002  2002   Dec          0               107.68
# 301   1/31/2003  2003   Jan          0               131.05
# 302   2/28/2003  2003   Feb          0               103.47
# 303   3/31/2003  2003   Mar          0               125.94
# 304   4/30/2003  2003   Apr          0               104.12
# 305   5/31/2003  2003   May          0                99.17
# 306   6/30/2003  2003   Jun          0                96.27
# 307   7/31/2003  2003   Jul          0               115.10
# 308   8/31/2003  2003   Aug          0               116.41
# 309   9/30/2003  2003   Sep          0               106.00
# 310  10/31/2003  2003   Oct          0               111.34
# 311  11/30/2003  2003   Nov          0                87.23
# 312  12/31/2003  2003   Dec          0                84.51
# 313   1/31/2004  2004   Jan          0               112.46
# 314   2/29/2004  2004   Feb          0                98.73
# 315   3/31/2004  2004   Mar          0               107.49
# 316   4/30/2004  2004   Apr          0                92.83
# 317   5/31/2004  2004   May          0               116.57
# 318   6/30/2004  2004   Jun          0                84.60
# 319   7/31/2004  2004   Jul          0                86.14
# 320   8/31/2004  2004   Aug          0               114.44
# 321   9/30/2004  2004   Sep          0                73.90
# 322  10/31/2004  2004   Oct          0               103.79
# 323  11/30/2004  2004   Nov          0                98.93
# 324  12/31/2004  2004   Dec          0                92.64
# 325   1/31/2005  2005   Jan          0                98.00
# 326   2/28/2005  2005   Feb          0                91.52
# 327   3/31/2005  2005   Mar          0               115.42
# 328   4/30/2005  2005   Apr          0               118.04
# 329   5/31/2005  2005   May          0                93.14
# 330   6/30/2005  2005   Jun          0               102.76
# 331   7/31/2005  2005   Jul          0                86.75
# 332   8/31/2005  2005   Aug          0               110.73
# 333   9/30/2005  2005   Sep          0               110.47
# 334  10/31/2005  2005   Oct          0                97.05
# 335  11/30/2005  2005   Nov          0               100.17
# 336  12/31/2005  2005   Dec          0                99.06
# 337   1/31/2006  2006   Jan          0                83.82
# 338   2/28/2006  2006   Feb          0               115.46
# 339   3/31/2006  2006   Mar          0                92.33
# 340   4/30/2006  2006   Apr          0                92.40
# 341   5/31/2006  2006   May          0                98.50
# 342   6/30/2006  2006   Jun          0               109.96
# 343   7/31/2006  2006   Jul          0                94.09
# 344   8/31/2006  2006   Aug          0                80.48
# 345   9/30/2006  2006   Sep          0                91.13
# 346  10/31/2006  2006   Oct          0               104.24
# 347  11/30/2006  2006   Nov          0               121.90
# 348  12/31/2006  2006   Dec          0                87.40
# 349   1/31/2007  2007   Jan          0                87.03
# 350   2/28/2007  2007   Feb          0                84.87
# 351   3/31/2007  2007   Mar          0                83.63
# 352   4/30/2007  2007   Apr          0               112.06
# 353   5/31/2007  2007   May          0               114.95
# 354   6/30/2007  2007   Jun          0               101.78
# 355   7/31/2007  2007   Jul          0                95.32
# 356   8/31/2007  2007   Aug          0               117.91
# 357   9/30/2007  2007   Sep          0               101.74
# 358  10/31/2007  2007   Oct          0               110.89
# 359  11/30/2007  2007   Nov          0                94.84
# 360  12/31/2007  2007   Dec          0               100.44
# 361   1/31/2008  2008   Jan          0                87.63
# 362   2/29/2008  2008   Feb          0               106.29
# 363   3/31/2008  2008   Mar          0               101.91
# 364   1/31/2010  2010   Jan          0               103.73
# 365   2/28/2010  2010   Feb          0               105.07
# 366   3/31/2010  2010   Mar          0               101.98
# 367   4/30/2010  2010   Apr          0                97.40
# 368   5/31/2010  2010   May          0               101.81
# 369   6/30/2010  2010   Jun          0               107.52
# 370   7/31/2010  2010   Jul          0               108.39
# 371   8/31/2010  2010   Aug          0               118.15
# 372   9/30/2010  2010   Sep          0                90.10
# 373  10/31/2010  2010   Oct          0                95.60
# 374  11/30/2010  2010   Nov          0                83.87
# 375  12/31/2010  2010   Dec          0               109.31
# 376   1/31/2011  2011   Jan          0                96.65
# 377   2/28/2011  2011   Feb          0               102.06
# 378   3/31/2011  2011   Mar          0                93.96
# 379   4/30/2011  2011   Apr          0                96.73
# 380   5/31/2011  2011   May          0               112.23
# 381   6/30/2011  2011   Jun          0               106.94
# 382   7/31/2011  2011   Jul          0                98.88
# 383   8/31/2011  2011   Aug          0               107.68
# 384   9/30/2011  2011   Sep          0               107.90
# 385  10/31/2011  2011   Oct          0                96.09
# 386  11/30/2011  2011   Nov          0                85.31
# 387  12/31/2011  2011   Dec          0                91.01
# 388   1/31/2012  2012   Jan          0                86.59
# 389   2/29/2012  2012   Feb          0               111.64
# 390   3/31/2012  2012   Mar          0               113.38
# 391   4/30/2012  2012   Apr          0               115.86
# 392   5/31/2012  2012   May          0                79.80
# 393   6/30/2012  2012   Jun          0               110.71
# 394   7/31/2012  2012   Jul          0               122.12
# 395   8/31/2012  2012   Aug          0               111.12
# 396   9/30/2012  2012   Sep          0                78.49
# 397  10/31/2012  2012   Oct          0               117.68
# 398  11/30/2012  2012   Nov          0               100.42
# 399  12/31/2012  2012   Dec          0                97.68
# 400   1/31/2013  2013   Jan          0               104.51
# 401   2/28/2013  2013   Feb          0                89.51
# 402   3/31/2013  2013   Mar          0               100.03
# 403   4/30/2013  2013   Apr          0               116.20
# 404   5/31/2013  2013   May          0               106.22
# 405   6/30/2013  2013   Jun          0               100.58
# 406   7/31/2013  2013   Jul          0               100.90
# 407   8/31/2013  2013   Aug          0                88.19
# 408   9/30/2013  2013   Sep          0                98.50
# 409  10/31/2013  2013   Oct          0                83.66
# 410  11/30/2013  2013   Nov          0               110.22
# 411  12/31/2013  2013   Dec          0                78.14
# 412   1/31/2014  2014   Jan          0               108.55
# 413   2/28/2014  2014   Feb          0               109.79
# 414   3/31/2014  2014   Mar          0               113.19
# 415   4/30/2014  2014   Apr          0               100.87
# 416   5/31/2014  2014   May          0               109.17
# 417   6/30/2014  2014   Jun          0                98.40
# 418   7/31/2014  2014   Jul          0                88.13
# 419   8/31/2014  2014   Aug          0               115.31
# 420   9/30/2014  2014   Sep          0                99.03
# 421  10/31/2014  2014   Oct          0                85.90
# 422  11/30/2014  2014   Nov          0                95.33
# 423  12/31/2014  2014   Dec          0                95.73
# 424   1/31/2015  2015   Jan          0               104.62
# 425   2/28/2015  2015   Feb          0               123.47
# 426   3/31/2015  2015   Mar          0               105.22
# 427   4/30/2015  2015   Apr          0               102.07
# 428   5/31/2015  2015   May          0               124.56
# 429   6/30/2015  2015   Jun          0               109.79
# 430   7/31/2015  2015   Jul          0               102.54
# 431   8/31/2015  2015   Aug          0                95.21
# 432   9/30/2015  2015   Sep          0               103.16
# 433  10/31/2015  2015   Oct          0                99.34
# 434  11/30/2015  2015   Nov          0               100.91
# 435  12/31/2015  2015   Dec          0               113.14
# 436   1/31/2016  2016   Jan          0                94.60
# 437   2/29/2016  2016   Feb          0               105.14
# 438   3/31/2016  2016   Mar          0               109.49
# 439   4/30/2016  2016   Apr          0                93.38
# 440   5/31/2016  2016   May          0                91.77
# 441   6/30/2016  2016   Jun          0                98.50
# 442   7/31/2016  2016   Jul          0                95.38
# 443   8/31/2016  2016   Aug          0               111.52
# 444   9/30/2016  2016   Sep          0                89.98
# 445  10/31/2016  2016   Oct          0               100.68
# 446  11/30/2016  2016   Nov          0               125.46
# 447  12/31/2016  2016   Dec          0               104.13
# 448   1/31/2017  2017   Jan          0               105.79
# 449   2/28/2017  2017   Feb          0               111.61
# 450   3/31/2017  2017   Mar          0                95.37
# 451   4/30/2017  2017   Apr          0                89.19
# 452   5/31/2017  2017   May          0               101.77
# 453   6/30/2017  2017   Jun          0               102.65
# 454   7/31/2017  2017   Jul          0                83.82
# 455   8/31/2017  2017   Aug          0               103.75
# 456   9/30/2017  2017   Sep          0               110.70
# 457  10/31/2017  2017   Oct          0                90.87
# 458  11/30/2017  2017   Nov          0               104.36
# 459  12/31/2017  2017   Dec          0               108.92
# 460   1/31/2018  2018   Jan          0               105.87
# 461   2/28/2018  2018   Feb          0               106.81
# 462   3/31/2018  2018   Mar          0                97.55
# 463   4/30/2018  2018   Apr          0                88.72
# 464   5/31/2018  2018   May          0                95.53
# 465   6/30/2018  2018   Jun          0                94.14
# 466   7/31/2018  2018   Jul          0                99.20
# 467   8/31/2018  2018   Aug          0               110.93
# 468   9/30/2018  2018   Sep          0                86.88
# 469  10/31/2018  2018   Oct          0               101.44
# 470  11/30/2018  2018   Nov          0                89.37
# 471  12/31/2018  2018   Dec          0                92.60
# 472   1/31/2019  2019   Jan          0               105.59
# 473   2/28/2019  2019   Feb          0                88.10
# 474   3/31/2019  2019   Mar          0               107.34
# 475   4/30/2019  2019   Apr          0                86.48
# 476   5/31/2019  2019   May          0               106.67
# 477   6/30/2019  2019   Jun          0                84.50
# 478   7/31/2019  2019   Jul          0                93.82
# 479   8/31/2019  2019   Aug          0               118.96
# 480   9/30/2019  2019   Sep          0               117.09
# 481  10/31/2019  2019   Oct          0                95.87
# 482  11/30/2019  2019   Nov          0               103.90
# 483  12/31/2019  2019   Dec          0               112.04
# 484   1/31/2020  2020   Jan          0               106.81
# 485   2/29/2020  2020   Feb          0                97.27
# 486   3/31/2020  2020   Mar          0                92.51
# 487   4/30/2020  2020   Apr          0               108.68
# 488   5/31/2020  2020   May          0               111.31
# 489   6/30/2020  2020   Jun          0               117.16
# 490   7/31/2020  2020   Jul          0                83.13
# 491   8/31/2020  2020   Aug          0                87.47
# 492   1/31/2021  2021   Jan          0                94.79
# 493   2/28/2021  2021   Feb          0               102.05
# 494   3/31/2021  2021   Mar          0                86.55
# 495   4/30/2021  2021   Apr          0               108.24
# 496   5/31/2021  2021   May          0               116.90
# 497   6/30/2021  2021   Jun          0               108.71
# 498   7/31/2021  2021   Jul          0                97.53
# 499   8/31/2021  2021   Aug          0                84.62
# 500   9/30/2021  2021   Sep          0                85.00
# 501  10/31/2021  2021   Oct          0                86.70
# 502  11/30/2021  2021   Nov          0                99.88
# 503  12/31/2021  2021   Dec          0               101.13
# 504   1/31/2022  2022   Jan          0               108.68
# 505   2/28/2022  2022   Feb          0                82.04
# 506   3/31/2022  2022   Mar          0               113.11
# 507   4/30/2022  2022   Apr          0               106.94
# 508   5/31/2022  2022   May          0                96.73
# 509   6/30/2022  2022   Jun          0                88.10
# 510   7/31/2022  2022   Jul          0               112.49
# 511   8/31/2022  2022   Aug          0                97.00
# 512   9/30/2022  2022   Sep          0                99.80
# 513  10/31/2022  2022   Oct          0               103.84
# 514  11/30/2022  2022   Nov          0                90.87
# 515  12/31/2022  2022   Dec          0                97.18
# 516   1/31/2023  2023   Jan          0               108.65
# 517   2/28/2023  2023   Feb          0               107.64
# 518   3/31/2023  2023   Mar          0               107.73
# 519   4/30/2023  2023   Apr          0                88.45
# 520   5/31/2023  2023   May          0                97.63
# 521   6/30/2023  2023   Jun          0                96.04
# 522   7/31/2023  2023   Jul          0               104.25
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# 2                  0.20  28238.443                     3137            3
# 3                  1.00  32615.149                     1653            7
# 4                  0.20  23829.233                     1319            4
# 5                  0.75  23829.315                     2573            5
# 6                  0.50  32896.064                     2828            3
# 7                  0.25  28837.174                     2917            3
# 8                  0.07  22652.628                     1138            3
# 9                  0.00  27712.800                     4582            5
# 10                 0.07  22682.912                     4939            5
# 11                 0.25  22671.351                     3892            6
# 12                 0.50  26209.811                     3026            8
# 13                 0.75  15433.599                     3306            9
# 14                 0.20  16375.411                     4744            4
# 15                 1.00  22188.562                     1901            6
# 16                 0.20  19935.844                     1689            4
# 17                 0.75  26571.237                     3039            9
# 18                 0.50  20459.880                     1009            8
# 19                 0.25  17938.481                     1260            5
# 20                 0.07  32328.244                     2942            8
# 21                 0.00  23871.118                     2673            5
# 22                 0.07  25337.641                     3219            9
# 23                 0.25  17876.259                     3945            8
# 24                 0.50  22278.086                     3060            6
# 25                 0.75  25554.613                     2191            7
# 26                 0.20  19245.032                     4713            6
# 27                 1.00  26878.490                     2619            4
# 28                 0.20  21996.807                     1320            6
# 29                 0.75  23541.531                     2342            9
# 30                 0.50  21991.467                     2636            3
# 31                 0.25  34261.391                     3376            4
# 32                 0.07  24932.514                     3832            8
# 33                 0.00  19711.445                     3824            4
# 34                 0.07  29112.725                     2994            7
# 35                 0.25  18895.782                     3958            5
# 36                 0.50  26044.318                     2943            8
# 37                 0.75  20453.063                     1477            3
# 38                 0.20  32013.972                     2254            9
# 39                 1.00  17990.745                     1922            5
# 40                 0.20  27934.285                     1419            3
# 41                 0.75  35952.278                     3204            5
# 42                 0.50  20047.318                     3597            7
# 43                 0.25  22168.511                     4512            3
# 44                 0.07  25498.257                     2120            6
# 45                 0.00  22482.622                     4068            8
# 46                 0.07  17246.683                     4044            8
# 47                 0.25  25342.815                     4482            5
# 48                 0.50  19688.481                     1950            9
# 49                 0.75  27367.962                     3336            6
# 50                 0.20  20402.879                     2277            3
# 51                 1.00  32749.672                     3243            6
# 52                 0.20  21083.734                     3645            6
# 53                 0.75  23389.692                     2857            9
# 54                 0.50  29067.586                     4593            3
# 55                 0.25  18845.678                     1516            7
# 56                 0.07  26137.300                     2658            9
# 57                 0.00  31535.714                     2865            6
# 58                 0.07  16962.584                     3912            6
# 59                 0.25  25923.169                     2141            7
# 60                 0.50  26299.414                     3853            6
# 61                 0.75  28909.114                     2932            6
# 62                 0.20  18815.246                     4230            6
# 63                 1.00  29328.776                     4208            9
# 64                 0.20  18998.518                     1201            3
# 65                 0.75  23327.494                     4507            6
# 66                 0.50  22625.273                     3360            9
# 67                 0.25  21733.354                     1116            7
# 68                 0.07  33827.271                     4737            5
# 69                 0.00  27024.909                     1936            7
# 70                 0.07  18695.580                     4874            6
# 71                 0.25  29589.310                     1574            3
# 72                 0.50  35610.781                     3291            9
# 73                 0.75  30162.326                     1536            7
# 74                 0.20  17403.150                     2625            7
# 75                 1.00  22578.830                     3122            3
# 76                 0.20  31334.556                     4877            9
# 77                 0.75  21461.653                     1385            5
# 78                 0.50  27219.097                     4974            3
# 79                 0.25  28873.170                     4281            7
# 80                 0.07  20365.348                     1474            5
# 81                 0.00  24702.373                     1417            5
# 82                 0.07   8793.663                     3394            3
# 83                 0.25  19878.062                     4600            7
# 84                 0.50  23737.159                     3687            6
# 85                 0.75  18761.084                     1938            7
# 86                 0.20  33162.057                     1954            4
# 87                 1.00  17849.293                     1875            9
# 88                 1.00  22181.377                     2920            7
# 89                 0.20  20888.898                     4335            6
# 90                 0.75  26218.436                     3972            5
# 91                 0.50  26224.833                     1054            8
# 92                 0.25  22465.284                     4942            3
# 93                 0.07  22644.808                     4714            7
# 94                 0.00  26160.250                     1799            5
# 95                 0.07  17759.578                     1777            4
# 96                 0.25  17962.681                     2481            8
# 97                 0.50  21407.779                     2901            9
# 98                 0.75  23932.764                     3209            9
# 99                 0.20  26554.538                     4451            3
# 100                1.00  32376.781                     3134            6
# 101                0.20  29288.298                     1054            3
# 102                0.75  24200.307                     4547            9
# 103                0.50  24904.919                     2823            4
# 104                0.25  19987.353                     2201            7
# 105                0.07  24907.434                     4462            7
# 106                0.00  23556.707                     4420            8
# 107                0.07  26613.593                     4079            7
# 108                0.25  20863.845                     1832            8
# 109                0.07  33435.708                     2622            8
# 110                0.00  29408.199                     4700            4
# 111                0.07  24960.137                     4945            8
# 112                0.25  32399.721                     1341            4
# 113                0.75  15201.649                     4621            4
# 114                1.50  18359.070                     3038            8
# 115                1.00  25984.306                     4490            8
# 116                1.50  28692.333                     4677            8
# 117                0.75  25856.841                     2118            5
# 118                0.50  24421.759                     4888            9
# 119                0.25  23494.482                     2604            6
# 120                0.07  17607.390                     3365            8
# 121                0.12  21400.779                     1235            3
# 122                0.25  22696.806                     2969            9
# 123                0.34  30285.611                     1333            7
# 124                0.50  26718.091                     2908            5
# 125                0.75  16184.799                     1375            4
# 126                1.50  26620.420                     4530            5
# 127                1.00  23074.589                     2160            4
# 128                1.50  21615.390                     3635            5
# 129                0.75  28058.381                     2570            4
# 130                0.50  30154.998                     3560            8
# 131                0.25  29656.401                     2319            6
# 132                0.07  20803.912                     4391            4
# 133                0.12  23453.938                     3965            4
# 134                0.25  26656.317                     4643            3
# 135                0.34  29877.726                     2855            4
# 136                0.50  22604.129                     2372            3
# 137                0.75  24071.705                     4911            7
# 138                1.50  19468.325                     4850            8
# 139                1.00  19018.967                     1872            3
# 140                1.50  29062.629                     2252            6
# 141                0.75  31781.200                     3317            9
# 142                0.50  24639.949                     2851            8
# 143                0.25  30017.664                     3845            3
# 144                0.07  26808.180                     2314            8
# 145                0.12  21774.401                     1724            8
# 146                0.25  26806.978                     4236            8
# 147                0.34  32690.183                     3052            7
# 148                0.50  24820.870                     3898            6
# 149                0.75  32823.218                     4450            5
# 150                1.50  11901.274                     1077            5
# 151                1.00  29109.513                     4481            3
# 152                1.50  25435.235                     3621            8
# 153                0.75  23504.963                     1131            3
# 154                0.50  25458.804                     1600            7
# 155                0.25  15062.155                     2772            7
# 156                0.07  23901.641                     2065            4
# 157                0.12  26785.563                     3136            7
# 158                0.25  32389.470                     3449            4
# 159                0.34  22408.649                     3343            6
# 160                0.50  20957.532                     2863            3
# 161                0.75  22491.215                     2318            9
# 162                1.50  29577.011                     1615            6
# 163                1.00  26643.756                     4597            7
# 164                1.50  22351.199                     3847            6
# 165                0.75  27566.337                     4762            6
# 166                0.50  25485.388                     4708            6
# 167                0.25  29843.225                     3469            7
# 168                0.07  21489.735                     2888            9
# 169                0.12  23361.689                     2046            8
# 170                0.25  23039.459                     1574            6
# 171                0.34  17682.425                     3190            4
# 172                0.50  26480.601                     1992            7
# 173                0.75  26305.276                     3712            6
# 174                1.50  25025.567                     3192            9
# 175                1.00  23827.064                     2248            8
# 176                1.50  17923.146                     4054            7
# 177                0.75  22896.773                     1502            5
# 178                0.50  23286.427                     2997            8
# 179                0.25  20988.614                     1820            4
# 180                0.07  24193.571                     4687            6
# 181                0.12  27020.254                     3151            9
# 182                0.25  34430.930                     4110            5
# 183                0.34  25872.889                     2970            9
# 184                0.50  26287.752                     1197            5
# 185                0.75  24627.770                     2669            7
# 186                1.50  15406.144                     3626            5
# 187                1.00  24867.431                     3438            4
# 188                1.50  25301.151                     2202            4
# 189                0.75  37316.211                     3601            3
# 190                0.50  24038.195                     2471            4
# 191                0.25  26507.737                     4571            8
# ...
# 71   Mediumfamilycar     Georgia
# 72     Supperminicar    New York
# 73   Smallfamiliycar     Georgia
# 74   Mediumfamilycar    Illinois
# 75   Smallfamiliycar  California
# 76     Supperminicar    Illinois
# 77   Mediumfamilycar     Georgia
# 78   Mediumfamilycar  California
# 79   Mediumfamilycar  California
# 80     Supperminicar     Georgia
# 81   Mediumfamilycar  California
# 82     Supperminicar     Georgia
# 83     Supperminicar     Georgia
# 84   Mediumfamilycar    Illinois
# 85     Supperminicar    New York
# 86   Smallfamiliycar    New York
# 87     Supperminicar     Georgia
# 88   Mediumfamilycar    Illinois
# 89   Mediumfamilycar  California
# 90   Mediumfamilycar  California
# 91   Mediumfamilycar  California
# 92     Supperminicar     Georgia
# 93   Smallfamiliycar  California
# 94   Smallfamiliycar    Illinois
# 95     Supperminicar    Illinois
# 96   Smallfamiliycar  California
# 97   Mediumfamilycar    New York
# 98     Supperminicar     Georgia
# 99   Smallfamiliycar     Georgia
# 100    Supperminicar  California
# 101    Supperminicar     Georgia
# 102  Mediumfamilycar    New York
# 103  Smallfamiliycar     Georgia
# 104  Smallfamiliycar    New York
# 105  Mediumfamilycar    Illinois
# 106    Supperminicar    New York
# 107  Smallfamiliycar     Georgia
# 108  Smallfamiliycar    Illinois
# 109  Mediumfamilycar    Illinois
# 110           Sports  California
# 111  Mediumfamilycar    New York
# 112  Smallfamiliycar    New York
# 113           Sports     Georgia
# 114  Smallfamiliycar  California
# 115    Supperminicar    Illinois
# 116  Smallfamiliycar  California
# 117  Mediumfamilycar    Illinois
# 118  Mediumfamilycar     Georgia
# 119     Executivecar  California
# 120           Sports    New York
# 121  Mediumfamilycar    Illinois
# 122  Mediumfamilycar  California
# 123    Supperminicar    Illinois
# 124    Supperminicar    New York
# 125  Mediumfamilycar    New York
# 126  Mediumfamilycar     Georgia
# 127           Sports    Illinois
# 128  Smallfamiliycar     Georgia
# 129    Supperminicar    New York
# 130  Mediumfamilycar    New York
# 131  Smallfamiliycar  California
# 132    Supperminicar    New York
# 133     Executivecar     Georgia
# 134  Smallfamiliycar    New York
# 135     Executivecar    Illinois
# 136  Smallfamiliycar     Georgia
# 137  Smallfamiliycar    Illinois
# 138  Mediumfamilycar    Illinois
# 139           Sports     Georgia
# 140  Mediumfamilycar     Georgia
# 141     Executivecar     Georgia
# 142  Smallfamiliycar    Illinois
# 143     Executivecar     Georgia
# 144  Smallfamiliycar    Illinois
# 145     Executivecar    Illinois
# 146  Mediumfamilycar  California
# 147           Sports     Georgia
# 148  Mediumfamilycar    Illinois
# 149    Supperminicar    New York
# 150    Supperminicar    Illinois
# 151           Sports  California
# 152  Mediumfamilycar    New York
# 153     Executivecar  California
# 154  Smallfamiliycar     Georgia
# 155  Mediumfamilycar  California
# 156    Supperminicar  California
# 157           Sports     Georgia
# 158     Executivecar    New York
# 159           Sports    New York
# 160  Smallfamiliycar  California
# 161     Executivecar    New York
# 162     Executivecar    Illinois
# 163  Mediumfamilycar    Illinois
# 164           Sports    Illinois
# 165           Sports  California
# 166           Sports     Georgia
# 167     Executivecar     Georgia
# 168  Smallfamiliycar     Georgia
# 169  Smallfamiliycar    Illinois
# 170           Sports  California
# 171    Supperminicar     Georgia
# 172     Executivecar    New York
# 173     Executivecar  California
# 174     Executivecar    Illinois
# 175           Sports    New York
# 176  Mediumfamilycar    New York
# 177  Mediumfamilycar    New York
# 178    Supperminicar    Illinois
# 179  Mediumfamilycar    New York
# 180  Smallfamiliycar    Illinois
# 181  Mediumfamilycar    New York
# 182           Sports     Georgia
# 183           Sports     Georgia
# 184  Smallfamiliycar    Illinois
# 185  Mediumfamilycar    New York
# 186           Sports     Georgia
# 187    Supperminicar    New York
# 188    Supperminicar  California
# 189  Smallfamiliycar    Illinois
# 190  Mediumfamilycar     Georgia
# 191  Smallfamiliycar    Illinois
# 192           Sports     Georgia
# 193  Mediumfamilycar    New York
# 194  Mediumfamilycar     Georgia
# 195  Smallfamiliycar     Georgia
# 196  Mediumfamilycar    New York
# 197     Executivecar     Georgia
# 198     Executivecar    Illinois
# 199     Executivecar  California
# 200  Mediumfamilycar    Illinois
# 201           Sports     Georgia
# 202           Sports     Georgia
# 203     Executivecar    New York
# 204    Supperminicar    New York
# 205    Supperminicar     Georgia
# 206  Smallfamiliycar     Georgia
# 207     Executivecar  California
# 208  Mediumfamilycar  California
# 209  Mediumfamilycar     Georgia
# 210           Sports    Illinois
# 211           Sports    New York
# 212           Sports  California
# 213  Mediumfamilycar    New York
# 214     Executivecar     Georgia
# 215  Smallfamiliycar  California
# 216  Smallfamiliycar    New York
# 217  Smallfamiliycar  California
# 218  Mediumfamilycar     Georgia
# 219  Mediumfamilycar     Georgia
# 220           Sports    Illinois
# 221  Smallfamiliycar  California
# 222     Executivecar    Illinois
# 223  Mediumfamilycar    New York
# 224  Smallfamiliycar     Georgia
# 225  Mediumfamilycar    Illinois
# 226  Smallfamiliycar    Illinois
# 227  Mediumfamilycar    New York
# 228  Mediumfamilycar  California
# 229  Smallfamiliycar    New York
# 230  Smallfamiliycar     Georgia
# 231  Mediumfamilycar  California
# 232           Sports    Illinois
# 233  Mediumfamilycar    New York
# 234     Executivecar     Georgia
# 235     Executivecar    New York
# 236           Sports    New York
# 237           Sports     Georgia
# 238  Mediumfamilycar     Georgia
# 239     Executivecar    New York
# 240           Sports    New York
# 241  Mediumfamilycar    New York
# 242  Mediumfamilycar     Georgia
# 243    Supperminicar    Illinois
# 244           Sports    Illinois
# 245           Sports     Georgia
# 246  Smallfamiliycar     Georgia
# 247  Mediumfamilycar     Georgia
# 248  Mediumfamilycar     Georgia
# 249  Smallfamiliycar    Illinois
# 250           Sports    New York
# 251  Smallfamiliycar    Illinois
# 252    Supperminicar    New York
# 253  Mediumfamilycar    New York
# 254     Executivecar    New York
# 255    Supperminicar  California
# 256     Executivecar  California
# 257  Mediumfamilycar    Illinois
# 258  Smallfamiliycar    New York
# 259  Smallfamiliycar    Illinois
# 260  Mediumfamilycar     Georgia
# 261  Smallfamiliycar  California
# 262           Sports  California
# 263           Sports    New York
# 264           Sports    Illinois
# 265  Smallfamiliycar    New York
# 266           Sports    Illinois
# 267  Mediumfamilycar    Illinois
# 268  Mediumfamilycar    Illinois
# 269    Supperminicar    Illinois
# 270    Supperminicar  California
# 271     Executivecar    Illinois
# 272  Mediumfamilycar  California
# 273  Smallfamiliycar  California
# 274     Executivecar    New York
# 275  Smallfamiliycar    Illinois
# 276  Mediumfamilycar  California
# 277  Mediumfamilycar     Georgia
# 278           Sports  California
# 279           Sports    New York
# 280  Mediumfamilycar    Illinois
# 281  Mediumfamilycar    New York
# 282  Mediumfamilycar    New York
# 283           Sports     Georgia
# 284  Mediumfamilycar    New York
# 285  Smallfamiliycar  California
# 286    Supperminicar    New York
# 287  Mediumfamilycar    New York
# 288  Mediumfamilycar    New York
# 289           Sports    Illinois
# 290  Smallfamiliycar    New York
# 291  Mediumfamilycar  California
# 292           Sports  California
# 293           Sports  California
# 294  Mediumfamilycar  California
# 295  Mediumfamilycar    New York
# 296  Mediumfamilycar  California
# 297           Sports    Illinois
# 298  Smallfamiliycar  California
# 299           Sports  California
# 300     Executivecar    New York
# 301  Mediumfamilycar     Georgia
# 302    Supperminicar    Illinois
# 303  Mediumfamilycar     Georgia
# 304  Mediumfamilycar    New York
# 305  Smallfamiliycar     Georgia
# 306     Executivecar  California
# 307           Sports     Georgia
# 308  Mediumfamilycar     Georgia
# 309     Executivecar    New York
# 310    Supperminicar  California
# 311  Mediumfamilycar    New York
# 312  Smallfamiliycar    Illinois
# 313     Executivecar    New York
# 314           Sports  California
# 315     Executivecar  California
# 316    Supperminicar  California
# 317  Mediumfamilycar  California
# 318  Mediumfamilycar    Illinois
# 319  Mediumfamilycar    Illinois
# 320           Sports    New York
# 321           Sports  California
# 322     Executivecar    Illinois
# 323  Mediumfamilycar  California
# 324  Smallfamiliycar    Illinois
# 325  Smallfamiliycar    Illinois
# 326  Mediumfamilycar    Illinois
# 327  Mediumfamilycar    Illinois
# 328     Executivecar  California
# 329     Executivecar  California
# 330    Supperminicar    New York
# 331  Mediumfamilycar     Georgia
# 332  Smallfamiliycar    Illinois
# 333  Smallfamiliycar  California
# 334           Sports     Georgia
# 335    Supperminicar     Georgia
# 336  Mediumfamilycar     Georgia
# 337  Smallfamiliycar    Illinois
# 338           Sports  California
# 339  Mediumfamilycar  California
# 340  Smallfamiliycar  California
# 341  Mediumfamilycar    New York
# 342     Executivecar     Georgia
# 343           Sports    New York
# 344  Smallfamiliycar    New York
# 345           Sports    New York
# 346           Sports    New York
# 347           Sports  California
# 348     Executivecar    Illinois
# 349     Executivecar    New York
# 350  Mediumfamilycar     Georgia
# 351     Executivecar    New York
# 352  Mediumfamilycar    Illinois
# 353     Executivecar    New York
# 354  Mediumfamilycar    Illinois
# 355     Executivecar     Georgia
# 356           Sports     Georgia
# 357  Smallfamiliycar  California
# 358           Sports  California
# 359  Mediumfamilycar     Georgia
# 360           Sports    Illinois
# 361  Mediumfamilycar    New York
# 362  Mediumfamilycar    Illinois
# 363           Sports  California
# 364  Smallfamiliycar  California
# 365           Sports    Illinois
# 366  Mediumfamilycar  California
# 367  Mediumfamilycar     Georgia
# 368  Mediumfamilycar  California
# 369  Mediumfamilycar    Illinois
# 370  Mediumfamilycar     Georgia
# 371    Supperminicar    New York
# 372  Smallfamiliycar  California
# 373    Supperminicar     Georgia
# 374           Sports  California
# 375           Sports    Illinois
# 376  Mediumfamilycar     Georgia
# 377     Executivecar  California
# 378  Mediumfamilycar     Georgia
# 379     Executivecar    Illinois
# 380           Sports    Illinois
# 381           Sports     Georgia
# 382  Mediumfamilycar     Georgia
# 383     Executivecar    New York
# 384  Smallfamiliycar     Georgia
# 385           Sports    New York
# 386    Supperminicar     Georgia
# 387     Executivecar     Georgia
# 388     Executivecar    New York
# 389     Executivecar    Illinois
# 390  Smallfamiliycar  California
# 391           Sports    New York
# 392  Smallfamiliycar  California
# 393     Executivecar    Illinois
# 394  Smallfamiliycar    New York
# 395  Mediumfamilycar    Illinois
# 396  Mediumfamilycar  California
# 397  Mediumfamilycar    New York
# 398  Smallfamiliycar     Georgia
# 399  Smallfamiliycar    Illinois
# 400  Mediumfamilycar    New York
# 401     Executivecar  California
# 402           Sports    Illinois
# 403    Supperminicar     Georgia
# 404  Mediumfamilycar     Georgia
# 405  Smallfamiliycar    Illinois
# 406    Supperminicar    Illinois
# 407     Executivecar  California
# 408     Executivecar    New York
# 409  Smallfamiliycar    New York
# 410  Smallfamiliycar  California
# 411    Supperminicar    New York
# 412           Sports    Illinois
# 413           Sports    Illinois
# 414  Smallfamiliycar    Illinois
# 415  Smallfamiliycar     Georgia
# 416           Sports    New York
# 417           Sports    New York
# 418  Mediumfamilycar  California
# 419    Supperminicar    Illinois
# 420    Supperminicar    Illinois
# 421  Mediumfamilycar    New York
# 422  Mediumfamilycar     Georgia
# 423    Supperminicar    Illinois
# 424  Mediumfamilycar    New York
# 425    Supperminicar  California
# 426     Executivecar    Illinois
# 427  Mediumfamilycar    New York
# 428    Supperminicar     Georgia
# 429  Mediumfamilycar    Illinois
# 430  Mediumfamilycar  California
# 431           Sports    New York
# 432  Mediumfamilycar     Georgia
# 433  Smallfamiliycar     Georgia
# 434     Executivecar    New York
# 435  Smallfamiliycar  California
# 436           Sports    Illinois
# 437  Mediumfamilycar    New York
# 438  Mediumfamilycar     Georgia
# 439    Supperminicar  California
# 440  Mediumfamilycar  California
# 441           Sports    Illinois
# 442           Sports    Illinois
# 443  Smallfamiliycar  California
# 444  Smallfamiliycar    Illinois
# 445           Sports    New York
# 446           Sports    Illinois
# 447    Supperminicar  California
# 448  Mediumfamilycar    Illinois
# 449  Mediumfamilycar    Illinois
# 450           Sports    New York
# 451    Supperminicar    Illinois
# 452  Smallfamiliycar    New York
# 453     Executivecar    New York
# 454    Supperminicar    Illinois
# 455  Mediumfamilycar    New York
# 456  Mediumfamilycar    Illinois
# 457  Mediumfamilycar    New York
# 458  Mediumfamilycar    New York
# 459  Mediumfamilycar    Illinois
# 460  Smallfamiliycar     Georgia
# 461  Mediumfamilycar     Georgia
# 462           Sports  California
# 463     Executivecar  California
# 464  Smallfamiliycar    New York
# 465  Smallfamiliycar    New York
# 466  Smallfamiliycar    Illinois
# 467  Mediumfamilycar     Georgia
# 468  Mediumfamilycar    New York
# 469     Executivecar    New York
# 470    Supperminicar    Illinois
# 471    Supperminicar    Illinois
# 472  Mediumfamilycar    Illinois
# 473     Executivecar  California
# 474  Smallfamiliycar    New York
# 475     Executivecar     Georgia
# 476  Smallfamiliycar  California
# 477           Sports    New York
# 478           Sports    Illinois
# 479  Smallfamiliycar  California
# 480  Smallfamiliycar     Georgia
# 481  Mediumfamilycar     Georgia
# 482  Smallfamiliycar  California
# 483     Executivecar  California
# 484           Sports  California
# 485     Executivecar    New York
# 486           Sports    Illinois
# 487  Mediumfamilycar  California
# 488  Smallfamiliycar  California
# 489     Executivecar  California
# 490  Mediumfamilycar     Georgia
# 491     Executivecar    Illinois
# 492  Smallfamiliycar    Illinois
# 493    Supperminicar    New York
# 494           Sports    New York
# 495  Smallfamiliycar     Georgia
# 496           Sports  California
# 497           Sports  California
# 498     Executivecar  California
# 499     Executivecar    New York
# 500  Mediumfamilycar    Illinois
# 501           Sports    Illinois
# 502  Smallfamiliycar    New York
# 503  Mediumfamilycar     Georgia
# 504     Executivecar     Georgia
# 505  Mediumfamilycar    New York
# 506  Mediumfamilycar    New York
# 507  Mediumfamilycar  California
# 508  Mediumfamilycar     Georgia
# 509           Sports    Illinois
# 510  Smallfamiliycar  California
# 511           Sports    Illinois
# 512     Executivecar    New York
# 513           Sports    New York
# 514  Mediumfamilycar    Illinois
# 515     Executivecar  California
# 516    Supperminicar  California
# 517           Sports  California
# 518    Supperminicar    New York
# 519           Sports     Georgia
# 520           Sports    New York
# 521  Smallfamiliycar    Illinois
# 522  Smallfamiliycar    New York
# 523     Executivecar    New York
# 524  Smallfamiliycar  California
# 525           Sports  California
# 526  Smallfamiliycar     Georgia
# 527  Smallfamiliycar     Georgia

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#     You will require:-
#     <br>create a separate dataframe where the column recession has a value of '1'
#     <br>to group the year, vehicle_type and calculate the average on the 'Automobile Sales'
#     <br>one way is to -
#     <br>use as_index as false else you will endup with multiple-indexed datafame
#     <br>later set year as index and groupby vehicle over Sales and plot
#     <br>make use of .plot() with kind = 'line'
#     <br>do not forget to include labels and title
# </p>
# </details>

# %%
df2=df[df['Recession']==1]
df2=df2.groupby(['Year','Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
df2.set_index('Year',inplace=True)
df2=df2.groupby('Vehicle_Type')['Automobile_Sales']
df2.head()
# Out:
# Year
# 1980    720.625000
# 1980    695.233333
# 1980    635.840000
# 1981    628.400000
# 1981    638.420000
# 1981    630.900000
# 1982    723.271429
# 1982    602.225000
# 1982    102.000000
# 1983    589.000000
# 1990    659.733333
# 1990    629.257143
# 1990    754.800000
# 1991    564.000000
# 1991    642.140000
# 1991    650.050000
# 1992    686.100000
# 2000    195.000000
# 2020    214.000000
# Name: Automobile_Sales, dtype: float64

# %%
df2.plot(kind='line')
plt.title('Sales Trend Vehicle-wise during Recession')
plt.ylabel('Automobile Sales')
plt.legend()
plt.show()

# %% [markdown]
# <details>
#     <summary>Click here for Solution template</summary>
#
# ```python
#     df_rec = df[df['Recession']==1]
#     df_Mline = df_rec.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean()
#     df_Mline.set_index('Year', inplace=True)
#     df_Mline = df_Mline.groupby(['Vehicle_Type'])['Automobile_Sales']
#     df_Mline.plot(kind='line')
#     plt.xlabel('..............')
#     plt.ylabel('............')
#     plt.title('Sales Trend Vehicle-wise during Recession')
#     plt.legend()
#     plt.show()
#
# ```
# </details>

# %%
df_rec = df[df['Recession']==1]
df_Mline = df_rec.groupby(['Year','Vehicle_Type'], as_index=False)['Automobile_Sales'].mean()
df_Mline.set_index('Year', inplace=True)
df_Mline = df_Mline.groupby(['Vehicle_Type'])['Automobile_Sales']
df_Mline.plot(kind='line')
plt.xlabel('..............')
plt.ylabel('............')
plt.title('Sales Trend Vehicle-wise during Recession')
plt.legend()
plt.show()

# %% [markdown]
# #### From the above plot, what insights have you gained on the sales of various vehicle types?<br> Type in your answer below:

# %% [markdown]
# <details>
#     <summary>Inference</summary>
# <p>
# Inference:
# From this plot, we can understand that during recession period, the sales for 'Sports type vehicles' declined because of the high cost of the vehicle.<br>while sales of the superminicar and smallfamilycar increased.<br><br>
#     </p>
#     </details>

# %% [markdown]
# <span style="color:red">
# Save this plot as "Line_Plot_2.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ----

# %% [markdown]
# ### TASK 1.3: Use the functionality of **Seaborn Library** to create a visualization to compare the sales trend per vehicle type for a recession period with a non-recession period.

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      To visualize the average number of vehicles sold during recession and non-recession periods, you can use a bar chart
#         <br> You will need to group recession average Automobile_Sales and then plot it<br>
#     Make use of sns.barplot(x=x,y=y, data = df)</p>
# </details>

# %%
df3=df.groupby('Recession')['Automobile_Sales'].mean().reset_index()
sns.barplot(df3,x='Recession',y='Automobile_Sales',hue='Recession')
# Out:
# <Axes: xlabel='Recession', ylabel='Automobile_Sales'>

# %% [markdown]
# <details>
#     <summary>Click here for Solution template</summary>
#
# ```python
#     new_df = df.groupby('Recession')['Automobile_Sales'].mean().reset_index()
#
#     # Create the bar chart using seaborn
#     plt.figure(figsize=(.........., ............)
#     sns.barplot(x='Recession', y='Automobile_Sales', hue='Recession',  data=new_df)
#     plt.xlabel('............')
#     plt.ylabel('...............')
#     plt.title('Average Automobile Sales during Recession and Non-Recession')
#     plt.xticks(ticks=[0, 1], labels=['Non-Recession', 'Recession'])
#     plt.show()
# ```
#
# </details>

# %%
new_df = df.groupby('Recession')['Automobile_Sales'].mean().reset_index()

# Create the bar chart using seaborn

sns.barplot(x='Recession', y='Automobile_Sales', hue='Recession',  data=new_df)
plt.xlabel('Recession')
plt.ylabel('Automobile Sales')
plt.title('Average Automobile Sales during Recession and Non-Recession')
plt.xticks(ticks=[0, 1], labels=['Non-Recession', 'Recession'])
plt.show()

# %% [markdown]
# ### Now you want to compare the sales of different vehicle types during a recession and a non-recession period
# <br>We recommend that you use the functionality of **Seaborn Library** to create this visualization

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      To visualize sales of different vehicles during recession and non-recession periods, you can use a bar chart
#         <br> You will need to group Recession, Vehicle_Type for average Automobile_Sales and then plot it<br>
#     Make use of sns.barplot(x=x,y=y, data = df)</p>
# </details>

# %%
df3=df.groupby(['Recession','Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
sns.barplot(df3,x='Recession',y='Automobile_Sales',hue='Vehicle_Type')
plt.title('Automobile Sales by Vehicle Type during Recession and Non-Recession Period')
plt.xticks(ticks=[0,1],labels=['Non-recession','Recession'])
plt.show()

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#    # Filter the data for recessionary periods
#     recession_data = df[df['Recession'] == 1]
#
#     dd=df.groupby(['Recession','Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
#
#     # Calculate the total sales volume by vehicle type during recessions
#     #sales_by_vehicle_type = recession_data.groupby('Vehicle_Type')['Automobile_Sales'].sum().reset_index()
#
#     # Create the grouped bar chart using seaborn
#     plt.figure(figsize=(10, 6))
#     sns.barplot(x='......', y='........', hue='Vehicle_Type', data=dd)
#     plt.xticks(ticks=[0, 1], labels=['Non-Recession', 'Recession'])
#     plt.xlabel('.............')
#     plt.ylabel('..............')
#     plt.title('Vehicle-Wise Sales during Recession and Non-Recession Period')
#
#     plt.show()
#
# ```
# </details>

# %%
recession_data = df[df['Recession'] == 1]

dd=df.groupby(['Recession','Vehicle_Type'])['Automobile_Sales'].mean().reset_index()

    # Calculate the total sales volume by vehicle type during recessions
    #sales_by_vehicle_type = recession_data.groupby('Vehicle_Type')['Automobile_Sales'].sum().reset_index()

    # Create the grouped bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Recession', y='Automobile_Sales', hue='Vehicle_Type', data=dd)
plt.xticks(ticks=[0, 1], labels=['Non-Recession', 'Recession'])
plt.xlabel('Recession')
plt.ylabel('Automobile_Sales')
plt.title('Vehicle-Wise Sales during Recession and Non-Recession Period')

plt.show()

# %% [markdown]
# ### From the above chart what insights have you gained on the overall sales of automobiles during recession? <br> Type your answer below:-

# %% [markdown]
# <details>
# <summary>Inference</summary>
#
# From this plot, we can understand that there is a drastic decline in the overall sales of the automobiles during recession.<br>However, the most affected type of vehicle is executivecar and sports<br><br>
# </details>

# %% [markdown]
# <span style="color:red">
# Save this plot as "Bar_Chart.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
# ### TASK 1.4: Use sub plotting to compare the variations in GDP during recession and non-recession period by developing line plots for each period.
# <br>Now, you want to find more insights from the data to understand the reason. <br>Plot a two line charts using subplotting to answer:-
# #### How did the GDP vary over time during recession and non-recession periods?
# <br>Make use of <u>add_subplot()</u> from Matplotlib for this comparision.

# %%
df0=df[df['Recession']==0]
df_gdp0=df0.groupby('Year')['GDP'].mean().reset_index()
df1=df[df['Recession']==1]
df_gdp1=df1.groupby('Year')['GDP'].mean().reset_index()
fig=plt.figure(figsize=(12,6))
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

sns.lineplot(df_gdp0,x='Year',y='GDP',ax=ax0)
ax0.set_title('GDP during Non-recession Periods')

sns.lineplot(df_gdp1,x='Year',y='GDP',ax=ax1)
ax1.set_title('GDP during Recession Periods')
plt.tight_layout()
plt.show()

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#     #Create dataframes for recession and non-recession period
#     rec_data = df[df['Recession'] == 1]
#     non_rec_data = df[df['Recession'] == 0]
#
#     #Figure
#     fig=plt.figure(figsize=(12, 6))
#
#     #Create different axes for subploting
#     ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
#     ax1 = fig.add_subplot(... ,... ,... ) # add subplot 2 (1 row, 2 columns, second plot).
#
#     #plt.subplot(1, 2, 1)
#     sns.lineplot(x='Year', y='GDP', data=rec_data, label='Recession', ax=ax0)
#     ax0.set_xlabel('Year')
#     ax0.set_ylabel('GDP')
#     ax0.set_title('GDP Variation during Recession Period')
#
#     #plt.subplot(1, 2, 2)
#     sns.lineplot(x='......', y='......', data=........, label='.........',ax=...)
#     ax1.set_xlabel('.....')
#     ax1.set_ylabel('.......')
#     ax1.set_title('..........')
#
#     plt.tight_layout()
#     plt.show()
#
#    #------------------------------------------------Alternatively--------------
#    #Using subplot()
#     plt.figure(figsize=(............, ..........))
#
#     #subplot 1
#     plt.subplot(1, 2, 1)
#     sns.lineplot(x='.........', y='......', data=.........., label='......')
#     plt.xlabel('.......')
#     plt.ylabel('..........')
#     plt.legend()
#     #subplot 1
#     plt.subplot(1, 2, 2)
#     sns.lineplot(x='.........', y='......', data=.........., label='......')
#     plt.xlabel('.......')
#     plt.ylabel('..........')
#     plt.legend()
#
#     plt.tight_layout()
#     plt.show()
# ```
# </details>

# %%
#Create dataframes for recession and non-recession period
rec_data = df[df['Recession'] == 1]
non_rec_data = df[df['Recession'] == 0]
    
    #Figure
fig=plt.figure(figsize=(12, 6))
    
    #Create different axes for subploting
ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1 ,2 ,2 ) # add subplot 2 (1 row, 2 columns, second plot). 
    
    #plt.subplot(1, 2, 1)
sns.lineplot(x='Year', y='GDP', data=rec_data, label='Recession', ax=ax0)
ax0.set_xlabel('Year')
ax0.set_ylabel('GDP')
ax0.set_title('GDP Variation during Recession Period')
    
    #plt.subplot(1, 2, 2)
sns.lineplot(x='Year', y='GDP', data=non_rec_data, label='Non-Recession', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('GDP')
ax1.set_title('GDP Variation during Non-Recession Period')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Inference
# From this plot, it is evident that during recession, the GDP of the country was in a low range, might have afected the overall sales of the company<br><br>
# <span style="color:red">
# Save this plot as "Subplot.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
# ### TASK 1.5: Develop a Bubble plot for displaying the impact of seasonality on Automobile Sales.
# <br>How has seasonality impacted the sales, in which months the sales were high or low? Check it for non-recession years to understand the trend
#
# ##### Develop a Bubble plot for displaying Automobile Sales for every month and use Seasonality Weight for representing the size of each bubble<br>
# Title this plot as 'Seasonality impact on Automobile Sales'

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      You can create Bubble Chart by calling the scatter()
#         <br>Pass the 'Month' and 'Automobile_Sales' to the functions as x and y and then use Seasonality weight for size parameter</p>
# </details>

# %%
sns.scatterplot(df0,x='Month',y='Automobile_Sales',size='Seasonality_Weight')
plt.title('Seasonality impact on Automobile Sales')
# Out:
# Text(0.5, 1.0, 'Seasonality impact on Automobile Sales')

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#     non_rec_data = df[df['Recession'] == 0]
#
#     size=non_rec_data['Seasonality_Weight'] #for bubble effect
#
#     sns.scatterplot(data=non_rec_data, x='........', y='........', size=size)
#
#     #you can further include hue='Seasonality_Weight', legend=False)
#
#     plt.xlabel('Month')
#     plt.ylabel('Automobile_Sales')
#     plt.title('Seasonality impact on Automobile Sales')
#
#     plt.show()
#
# ```
# </details>

# %%
non_rec_data = df[df['Recession'] == 0]
    
size=non_rec_data['Seasonality_Weight'] #for bubble effect
    
sns.scatterplot(data=non_rec_data, x='Month', y='Automobile_Sales', size=size)
    
    #you can further include hue='Seasonality_Weight', legend=False)

plt.xlabel('Month')
plt.ylabel('Automobile_Sales')
plt.title('Seasonality impact on Automobile Sales')

plt.show()

# %% [markdown]
# ### Inference
# From this plot, it is evident that seasonality has not affected on the overall sales. However, there is a drastic raise in sales in the month of April<br><br>
# <span style="color:red">
# Save this plot as "Bubble.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
#  ### TASK 1.6: Use the functionality of Matplotlib to develop a scatter plot to identify the correlation between average vehicle price relate to the sales volume during recessions.
#  #### From the data, develop a scatter plot to identify if there a correlation between consumer confidence and automobile sales during recession period?
#  <br> Title this plot as 'Consumer Confidence and Automobile Sales during Recessions'

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      You can create dataframe where recession is '1'.
#         <br>Pass the 'Consumer_Confidence' and 'Automobile_Sales' to the plt.scatter()</p>
# </details>

# %%
sns.scatterplot(df1,x='Consumer_Confidence',y='Automobile_Sales')
# Out:
# <Axes: xlabel='Consumer_Confidence', ylabel='Automobile_Sales'>

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#     #Create dataframes for recession and non-recession period
#     rec_data = df[df['Recession'] == 1]
#     plt.scatter(rec_data['Consumer_Confidence'], rec_data['Automobile_Sales'])
#
#     plt.xlabel('.....')
#     plt.ylabel('.......')
#     plt.title('..........')
#     plt.show()
#
# ```
# </details>

# %% [markdown]
#  ### How does the average vehicle price relate to the sales volume during recessions?
#  <br> Plot another scatter plot and title it as 'Relationship between Average Vehicle Price and Sales during Recessions'

# %%
sns.scatterplot(df1,x='Price',y='Automobile_Sales')
plt.title('Relationship between Average Vehicle Price and Sales during Recessions')
plt.xlabel('Average Vehicle Price')
plt.ylabel('Automobile_Sales')
plt.show()

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#     #Create dataframes for recession and non-recession period
#     rec_data = df[df['Recession'] == 1]
#     plt.scatter(recession_data['Price'], rec_data['Automobile_Sales'])
#
#     plt.xlabel('.....')
#     plt.ylabel('.......')
#     plt.title('..........')
#     plt.show()
#
# ```
# </details>

# %% [markdown]
# ### Inference
# There is not much relation!<br><br>
# <span style="color:red">
# Save this plot as "Scatter.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ----

# %% [markdown]
#  ### TASK 1.7: Create a pie chart to display the portion of advertising expenditure of XYZAutomotives during recession and non-recession periods.
#  <br>How did the advertising expenditure of XYZAutomotives change during recession and non-recession periods?

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      You can create two dataframe for recession and nonreccession period.
#     <br> Calculate the sum of Advertising_Expenditure for both dataframes
#     <br> Pass these total values to plt.pie(). May include labels as ['Recession', 'Non-Recession']
#         <br>Feel Free to customie the pie further
#     <br>title this plot as  - Advertising Expenditure during Recession and Non-Recession Periods</p>
# </details>

# %%
df0ae=df0['Advertising_Expenditure'].sum()
df1ae=df1['Advertising_Expenditure'].sum()
plt.pie([df0ae,df1ae],labels=['Non-recession','Recession'],autopct='%1.1f%%')
plt.title('AD Expenditures during Recession and Non-recession Periods')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <details>
# <summary>Click here for Solution template</summary>
#
# ```python
#     # Filter the data
#     Rdata = df[df['Recession'] == 1]
#     NRdata = df[df['Recession'] == 0]
#
#     # Calculate the total advertising expenditure for both periods
#     RAtotal = Rdata['...........'].sum()
#     NRAtotal = NRdata['...........'].sum()
#
#     # Create a pie chart for the advertising expenditure
#     plt.figure(figsize=(8, 6))
#
#     labels = ['Recession', 'Non-Recession']
#     sizes = [RAtotal, NRtotal]
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
#
#     plt.title('...........................')
#
#     plt.show()
#
#
# ```
# </details>

# %% [markdown]
# #### From the above plot, what insights do you find on the advertisement expenditure during recession and non recession periods?<br> Type your answer below:-

# %% [markdown]
# <details><summary>Inference</summary>
# It seems ABCAutomotives has been spending much more on the advertisements during non-recession periods as compared to during recession times. Fair enough!<br><br></details>

# %% [markdown]
# <span style="color:red">
# Save this plot as "Pie_1.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
# ### TASK 1.8: Develop a pie chart to display the total Advertisement expenditure for each vehicle type during recession period.<br>
# Can we observe the share of each vehicle type in total expenditure during recessions?

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#      You will be required to group vehicle type for sum of advertisement expenditure.
#     <br> the plot a pie with the data, May include relevant labels
#     <br>title this plot as  - Share of Each Vehicle Type in Total Expenditure during Recessions</p>
# </details>

# %%
df_pie=df1.groupby('Vehicle_Type')['Advertising_Expenditure'].sum()
plt.figure(figsize=(10,8))
plt.pie(df_pie,autopct='%1.1f%%',labels=df_pie.index)
plt.legend(df_pie.index)
plt.title('The Share of Each Vehicle Type in Ad Expenditure')
plt.show()

# %% [markdown]
# <details>
#     <summary>Click here for Solution template</summary>
#
# ```python
#     # Filter the data
#     Rdata = df[df['Recession'] == 1]
#
#     # Calculate the sales volume by vehicle type during recessions
#     VTexpenditure = Rdata.groupby('..........')['.............'].sum()
#
#     # Create a pie chart for the share of each vehicle type in total expenditure during recessions
#     plt.figure(figsize=(..., ...))
#
#     labels = VTexpenditure.index
#     sizes = VTexpenditure.values
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
#
#     plt.title('....................')
#
#     plt.show()
# ```
#     </details>

# %% [markdown]
# ### Inference
# During recession the advertisements were mostly focued on low price range vehicle. A wise decision!<br><br>
# <span style="color:red">
# Save this plot as "Pie_2.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ----

# %% [markdown]
#  ### TASK 1.9: Develop a lineplot to analyse the effect of the unemployment rate on vehicle type and sales during the Recession Period.
#  <br>Analyze the effect of the unemployment rate on vehicle type and sales during the Recession Period
#  #### You can create a lineplot and title the plot as 'Effect of Unemployment Rate on Vehicle Type and Sales'

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# <p>
#     Filter out the data for recession period<br>
#      Make use of lineplot() from seaborn and pass the relavent data</p>
# </details>

# %%
sns.lineplot(data=df1, x='unemployment_rate', y='Automobile_Sales',
             hue='Vehicle_Type', style='Vehicle_Type', markers='o', err_style=None)
plt.ylim(0,850)
plt.legend(loc=(0.05,.3))
plt.title('Effect of Unemployment Rate on Vehicle Type and Sales')
# Out:
# C:\Users\Sywliray\AppData\Local\Temp\ipykernel_75908\4118239455.py:1: UserWarning:
# The markers list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=df1, x='unemployment_rate', y='Automobile_Sales',
# Text(0.5, 1.0, 'Effect of Unemployment Rate on Vehicle Type and Sales')

# %% [markdown]
# <details>
#     <summary>Click here for Solution template</summary>
#
# ```python
# df_rec = df[df['Recession']==1]
# sns.lineplot(data=df_rec, x='..........', y='.........',
#              hue='Vehicle_Type', style='Vehicle_Type', markers='o', err_style=None)
# plt.ylim(0,850)
# plt.legend(loc=(0.05,.3))
# ```
#
# </details>

# %% [markdown]
# #### From the above plot, what insights have you gained on the sales of superminicar, smallfamilycar, mediumminicar?<br> Type your answer below:-

# %% [markdown]
# <details><summary>Inference</summary>
# During recession, buying pattern changed, the sales of low range vehicle like superminicar,smallfamilycar and Mediumminicar<br><br>
# </details>

# %% [markdown]
# <span style="color:red">
# Save this plot as "line_plot_3.png"</span><br>
# *Hint: You can right lick on the plot and then click on "Save image as" option to save it on your local machine*

# %% [markdown]
# ---

# %% [markdown]
# ### OPTIONAL : TASK 1.10 Create a map on the hightest sales region/offices of the company during recession period

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/us-states.json'
await download(path, "us-states.json")

filename = "us-states.json"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 from pyodide.http import pyfetch
#       3 async def download(url, filename):
#       4     response = await pyfetch(url)
#
# ModuleNotFoundError: No module named 'pyodide'

# %% [markdown]
# #### You found that the datset also contains the location/city for company offices. Now you want to show the recession impact on various offices/city sales by developing a choropleth

# %%
    # Filter the data for the recession period and specific cities
recession_data = data[data['Recession'] == 1]

    # Calculate the total sales by city
sales_by_city = recession_data.groupby('City')['Automobile_Sales'].sum().reset_index()

    # Create a base map centered on the United States
map1 = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

    # Create a choropleth layer using Folium
choropleth = folium.Choropleth(
    geo_data= 'us-states.json',  # GeoJSON file with state boundaries
    data=sales_by_city,
    columns=['City', 'Automobile_Sales'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Automobile Sales during Recession'
    ).add_to(map1)


    # Add tooltips to the choropleth layer
choropleth.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'], labels=True)
    )

    # Display the map
map1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[148], line 2
#       1     # Filter the data for the recession period and specific cities
# ----> 2 recession_data = data[data['Recession'] == 1]
#       4     # Calculate the total sales by city
#       5 sales_by_city = recession_data.groupby('City')['Automobile_Sales'].sum().reset_index()
#
# NameError: name 'data' is not defined

# %% [markdown]
# <details><summary>Click for Solution</summary>
#
# ```python
#
#     # Filter the data for the recession period and specific cities
#     recession_data = data[data['Recession'] == 1]
#
#     # Calculate the total sales by city
#     sales_by_city = recession_data.groupby('City')['Automobile_Sales'].sum().reset_index()
#
#     # Create a base map centered on the United States
#     map1 = folium.Map(location=[37.0902, -95.7129], zoom_start=4)
#
#     # Create a choropleth layer using Folium
#     choropleth = folium.Choropleth(
#         geo_data= 'us-states.json',  # GeoJSON file with state boundaries
#         data=sales_by_city,
#         columns=['City', 'Automobile_Sales'],
#         key_on='feature.properties.name',
#         fill_color='YlOrRd',
#         fill_opacity=0.7,
#         line_opacity=0.2,
#         legend_name='Automobile Sales during Recession'
#     ).add_to(map1)
#
#
#     # Add tooltips to the choropleth layer
#     choropleth.geojson.add_child(
#         folium.features.GeoJsonTooltip(['name'], labels=True)
#     )
#
#     # Display the map
#     map1
#
# ```
# </details>

# %% [markdown]
# # Congratulations! You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# [Dr. Pooja](author_link)

# %% [markdown]
# ``` toggle ## Change Log
# ```

# %% [markdown]
# <!---|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# 2024-01-05|0.2.1|Sowmyaa Gurusamy|Updated the lab instructions|
# |2023-06-17|0.2|Pooja|Initial Lab Creation|
# |2023-05-01|0.1|Shengkai|Create Lab Template|-->

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
