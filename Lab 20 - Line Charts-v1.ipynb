# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Line Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on using line charts to analyze trends over time and across different categories in a dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Track trends in compensation across age groups and specific age ranges.
#
# - Analyze job satisfaction trends based on experience level.
#
# - Explore and interpret line charts to identify patterns and trends.

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %% [markdown]
# #### Step 1: Download the dataset

# %%
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# %% [markdown]
# #### Step 2: Import necessary libraries and load the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv("cleaned-data.csv")

# %% [markdown]
# #### Display the first few rows to understand the structure of the data

# %%
df.head()
# Out:
#    Unnamed: 0  ResponseId                      MainBranch                 Age  \
# 0           0           1  I am a developer by profession  Under 18 years old
# 1           1           2  I am a developer by profession     35-44 years old
# 2           2           3  I am a developer by profession     45-54 years old
# 3           3           4           I am learning to code     18-24 years old
# 4           4           5  I am a developer by profession     18-24 years old
#
#             Employment                            RemoteWork   Check  \
# 0  Employed, full-time                                Remote  Apples
# 1  Employed, full-time                                Remote  Apples
# 2  Employed, full-time                                Remote  Apples
# 3   Student, full-time  Hybrid (some remote, some in-person)  Apples
# 4   Student, full-time  Hybrid (some remote, some in-person)  Apples
#
#                                                    CodingActivities  \
# 0                                                             Hobby
# 1  Hobby;Contribute to open-source projects;Other (please specify):
# 2  Hobby;Contribute to open-source projects;Other (please specify):
# 3                                                               NaN
# 4                                                               NaN
#
#                                                                               EdLevel  \
# 0                                                           Primary/elementary school
# 1                                        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3                              Some college/university study without earning a degree
# 4  Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
#
#                                                                                                                                                             LearnCode  \
# 0                                                                                                                                              Books / Physical media
# 1                                          Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community)
# 2  Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)
# 3                       Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification
# 4                                                                                               Other online resources (e.g., videos, blogs, forum, online community)
#
#                                                                                                         LearnCodeOnline  \
# 0                                                                                                                   NaN
# 1                                                  Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow
# 2  Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);Social Media
# 3                                                                     Stack Overflow;How-to videos;Interactive tutorial
# 4                Technical documentation;Blogs;Written Tutorials;Stack Overflow;Social Media;Video-based Online Courses
#
#                                                                                                                                                          TechDoc  \
# 0                                                                                                                                                            NaN
# 1  API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine
# 2                             API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine
# 3                                                                                                                                                            NaN
# 4  API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine
#
#   YearsCode YearsCodePro                DevType OrgSize PurchaseInfluence  \
# 0       NaN            2                    NaN     NaN               NaN
# 1        20           17  Developer, full-stack     NaN               NaN
# 2        37           27   Developer Experience     NaN               NaN
# 3         4            2  Developer, full-stack     NaN               NaN
# 4         9            2  Developer, full-stack     NaN               NaN
#
#   BuyNewTool BuildvsBuy TechEndorse  \
# 0        NaN        NaN         NaN
# 1        NaN        NaN         NaN
# 2        NaN        NaN         NaN
# 3        NaN        NaN         NaN
# 4        NaN        NaN         NaN
#
#                                                 Country Currency  \
# 0                              United States of America      NaN
# 1  United Kingdom of Great Britain and Northern Ireland      NaN
# 2  United Kingdom of Great Britain and Northern Ireland      NaN
# 3                                                Canada      NaN
# 4                                                Norway      NaN
#
#        CompTotal  \
# 0  2.963490e+145
# 1   5.085000e+04
# 2  2.963490e+145
# 3  2.963490e+145
# 4  2.963490e+145
#
#                                                   LanguageHaveWorkedWith  \
# 0                                         HTML/CSS;JavaScript;TypeScript
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript
# 2                                                                     C#
# 3    C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript
# 4                                C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                                                          LanguageWantToWorkWith  \
# 0                                                                        Python
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Kotlin;Python;TypeScript
# 2                                                                            C#
# 3                     HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript
# 4                                            C++;HTML/CSS;JavaScript;Lua;Python
#
#                                                          LanguageAdmired  \
# 0                                                                    NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript
# 2                                                                     C#
# 3              HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript
# 4                                     C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                       PostgreSQL                  PostgreSQL
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use  \
# 0                   NaN
# 1                 MacOS
# 2               Windows
# 3                   NaN
# 4                   NaN
#
#                                        OfficeStackAsyncHaveWorkedWith  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3                                                                 NaN
# 4  GitHub Discussions;Markdown File;Obsidian;Stack Overflow for Teams
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                                                                                                   NEWSOSites  \
# 0                                                          I have never visited Stack Overflow or the Stack Exchange network
# 1  Stack Overflow for Teams (private knowledge sharing & collaboration platform for companies);Stack Overflow;Stack Exchange
# 2                                                               Stack Overflow;Stack Exchange;Stack Overflow Blog or Podcast
# 3                                                                                                             Stack Overflow
# 4  Stack Overflow for Teams (private knowledge sharing & collaboration platform for companies);Stack Overflow;Stack Exchange
#
#               SOVisitFreq SOAccount              SOPartFreq  \
# 0                     NaN       NaN                     NaN
# 1  Multiple times per day       Yes  Multiple times per day
# 2  Multiple times per day       Yes  Multiple times per day
# 3   Daily or almost daily        No                     NaN
# 4  Multiple times per day       Yes  Multiple times per day
#
#                                                                                                                                                                                                                                                                                                                    SOHow  \
# 0                                                                                                                                                                                                                                                                                                                    NaN
# 1                                                                                          Quickly finding code solutions;Finding reliable guidance from community-vetted answers;Showcase expertise with code solutions;Engage with community by commenting on questions and answers or voting on questions and answers
# 2  Quickly finding code solutions;Finding reliable guidance from community-vetted answers;Showcase expertise with code solutions;Engage with community by commenting on questions and answers or voting on questions and answers;Learning new-to-me technology/techniques;Learning new-to-everyone technology/techniques
# 3                                                                                                                                                                                                                                                                                         Quickly finding code solutions
# 4                                                                                                                        Quickly finding code solutions;Engage with community by commenting on questions and answers or voting on questions and answers;Learning new-to-me technology/techniques;Other (please specify):
#
#             SOComm                 AISelect          AISent  \
# 0              NaN                      Yes  Very favorable
# 1  Yes, definitely  No, and I don't plan to             NaN
# 2  Yes, definitely  No, and I don't plan to             NaN
# 3   No, not really                      Yes  Very favorable
# 4  Yes, definitely  No, and I don't plan to             NaN
#
#                                                                                                          AIBen  \
# 0                                                                                        Increase productivity
# 1                                                                                                          NaN
# 2                                                                                                          NaN
# 3  Increase productivity;Greater efficiency;Improve collaboration;Speed up learning;Improve accuracy in coding
# 4                                                                                                          NaN
#
#             AIAcc                      AIComplex  \
# 0             NaN                            NaN
# 1             NaN                            NaN
# 2             NaN                            NaN
# 3  Somewhat trust  Bad at handling complex tasks
# 4             NaN                            NaN
#
#                                                                                                                                                                    AIToolCurrently Using  \
# 0                                                                                                                                                                                    NaN
# 1                                                                                                                                                                                    NaN
# 2                                                                                                                                                                                    NaN
# 3  Learning about a codebase;Project planning;Writing code;Documenting code;Debugging and getting help;Deployment and monitoring;Search for answers;Generating content or synthetic data
# 4                                                                                                                                                                                    NaN
#
#                                          AIToolInterested in Using  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3  Testing code;Committing and reviewing code;Predictive analytics
# 4                                                              NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                                                                                                                                               AINextMuch more integrated  \
# 0                                                                                                                                                                                    NaN
# 1                                                                                                                                                                                    NaN
# 2                                                                                                                                                                                    NaN
# 3  Learning about a codebase;Project planning;Writing code;Documenting code;Debugging and getting help;Deployment and monitoring;Search for answers;Generating content or synthetic data
# 4                                                                                                                                                                                    NaN
#
#   AINextNo change AINextMore integrated AINextLess integrated  \
# 0             NaN                   NaN                   NaN
# 1             NaN                   NaN                   NaN
# 2             NaN                   NaN                   NaN
# 3             NaN                   NaN                   NaN
# 4             NaN                   NaN                   NaN
#
#   AINextMuch less integrated AIThreat  \
# 0                        NaN      NaN
# 1                        NaN      NaN
# 2                        NaN      NaN
# 3                        NaN       No
# 4                        NaN      NaN
#
#                                                                                             AIEthics  \
# 0                                                                                                NaN
# 1                                                                                                NaN
# 2                                                                                                NaN
# 3  Circulating misinformation or disinformation;Missing or incorrect attribution for sources of data
# 4                                                                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  \
# 0                                NaN      No                     NaN
# 1                                NaN     Yes  Individual contributor
# 2                                NaN      No                     NaN
# 3  Don’t trust the output or answers     NaN                     NaN
# 4                                NaN     NaN                     NaN
#
#      WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0  11.466323         NaN         NaN         NaN         NaN         NaN
# 1  17.000000       Agree    Disagree       Agree       Agree       Agree
# 2  11.466323         NaN         NaN         NaN         NaN         NaN
# 3  11.466323         NaN         NaN         NaN         NaN         NaN
# 4  11.466323         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3        TimeSearching        TimeAnswering  \
# 0         NaN         NaN  30-60 minutes a day  15-30 minutes a day
# 1         NaN         NaN  30-60 minutes a day  15-30 minutes a day
# 2         NaN         NaN  30-60 minutes a day  15-30 minutes a day
# 3         NaN         NaN  30-60 minutes a day  15-30 minutes a day
# 4         NaN         NaN  30-60 minutes a day  15-30 minutes a day
#
#   Frustration ProfessionalTech ProfessionalCloud ProfessionalQuestion  \
# 0         NaN              NaN               NaN                  NaN
# 1         NaN              NaN               NaN                  NaN
# 2         NaN              NaN               NaN                  NaN
# 3         NaN              NaN               NaN                  NaN
# 4         NaN              NaN               NaN                  NaN
#
#   Industry  JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0      NaN             NaN             NaN             NaN       24.339971
# 1      NaN             0.0             0.0             0.0        0.000000
# 2      NaN             NaN             NaN             NaN       24.339971
# 3      NaN             NaN             NaN             NaN       24.339971
# 4      NaN             NaN             NaN             NaN       24.339971
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN         86158.926569
# 1              0.0                    NaN        NaN         41000.500000
# 2              NaN  Appropriate in length       Easy         86158.926569
# 3              NaN               Too long       Easy         86158.926569
# 4              NaN              Too short       Easy         86158.926569
#
#      JobSat  age_simulated
# 0  6.934915             12
# 1  7.000000             39
# 2  6.934915             54
# 3  6.934915             18
# 4  6.934915             20

# %% [markdown]
# ### Task 1: Trends in Compensation Over Age Groups

# %% [markdown]
# ##### 1. Line Chart of Median `ConvertedCompYearly` by Age Group

# %% [markdown]
# - Track how the median yearly compensation (ConvertedCompYearly) changes across different age groups.
#
# - Use a line chart to visualize these trends.

# %%
## Write your code here
label1=['Under 18 years old', '18-24 years old', '25-34 years old', '35-44 years old', '45-54 years old',
       '55-64 years old', '65 years or older','Prefer not to say']
label2=['0-18','18-24','25-34','35-44','45-54','55-64','65-100','Prefer not to say']
# 构建映射字典
# 初始化新列
df['map_age'] = df['Age']  # 先复制原列，避免覆盖

# 遍历 label1 和 label2，逐个替换
for l1, l2 in zip(label1, label2):
    df.loc[df['Age'] == l1, 'map_age'] = l2  # 条件筛选并替换
df['map_age'].head()
# Out:
# 0     0-18
# 1    35-44
# 2    45-54
# 3    18-24
# 4    18-24
# Name: map_age, dtype: object

# %%
df_l1=df.groupby('map_age')['ConvertedCompYearly'].median().reset_index()
df_l1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ##### 2. Line Chart of Median `ConvertedCompYearly` for Ages 25 to 45

# %% [markdown]
# For a closer look, plot a line chart focusing on the median compensation for respondents between ages 25 and 45.

# %%
## Write your code here

# %% [markdown]
# ### Task 2: Trends in Job Satisfaction by Experience Level

# %% [markdown]
# ##### 1. Line Chart of Job Satisfaction (`JobSatPoints_6`) by Experience Level

# %% [markdown]
# - Use a column that approximates experience level to analyze how job satisfaction changes with experience.
#
# - If needed, substitute an available experience-related column for `Experience`.

# %%
## Write your code here
df6=df.groupby('WorkExp')['JobSatPoints_6'].mean().reset_index()
df6.plot.line(x='WorkExp',y='JobSatPoints_6')
# Out:
# <Axes: xlabel='WorkExp'>

# %% [markdown]
# ### Task 3: Trends in Job Satisfaction and Compensation by Experience

# %% [markdown]
# ##### 1.Line Chart of Median ConvertedCompYearly Over Experience Level
#
# - This line chart will track how median compensation (`ConvertedCompYearly`) changes with increasing experience.
#
# - Use a column such as `WorkExp` or another relevant experience-related column.

# %%
## Write your code here
df7=df.groupby('WorkExp')['ConvertedCompYearly'].median().reset_index()
df7.plot.line(x='WorkExp',y='ConvertedCompYearly')
# Out:
# <Axes: xlabel='WorkExp'>

# %% [markdown]
# ##### 2.Line Chart of Job Satisfaction (`JobSatPoints_6`) Across Experience Levels
#
# - Create a line chart to explore trends in job satisfaction (`JobSatPoints_6`) based on experience level.
#
# - This chart will provide insight into how satisfaction correlates with experience over time

# %%
## Write your code here

# %% [markdown]
# #### Final Step: Review

# %% [markdown]
# In this lab, you focused on analyzing trends in compensation and job satisfaction, specifically exploring how these metrics change with age and experience levels using line charts.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you explored essential data visualization techniques with a focus on analyzing trends using line charts. You learned to:
#
# - Visualize the distribution of compensation across age groups to understand salary trends.
#
# - Track changes in median compensation over various experience levels, identifying how earnings progress with experience.
#
# - Examine trends in job satisfaction by experience, revealing how satisfaction varies throughout a developer's career.
#
# These analyses allow for a deeper understanding of how factors like age and experience influence job satisfaction and compensation. By using line charts, you gained insights into continuous data patterns, which are invaluable for interpreting professional trends in the developer community.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
